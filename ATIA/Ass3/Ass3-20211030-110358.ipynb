# %%
# !apt update && apt install ffmpeg libsm6 libxext6  -y
# !pip install -U scikit-image
# !pip install opencv-python
# !pip install opencv-contrib-python
# Out:
# Get:1 http://deb.debian.org/debian buster InRelease [122 kB]
# Get:2 http://security.debian.org/debian-security buster/updates InRelease [65.4 kB]
# Get:3 http://deb.debian.org/debian buster-updates InRelease [51.9 kB]
# Get:4 http://security.debian.org/debian-security buster/updates/main amd64 Packages [308 kB]
# Get:5 http://deb.debian.org/debian buster/main amd64 Packages [7,906 kB]
# Get:6 http://deb.debian.org/debian buster-updates/main amd64 Packages [15.2 kB]
# Fetched 8,469 kB in 4s (2,134 kB/s)
#
#
#
# 2 packages can be upgraded. Run 'apt list --upgradable' to see them.
#
#
#
# libsm6 is already the newest version (2:1.2.3-1).
# libsm6 set to manually installed.
# libxext6 is already the newest version (2:1.3.3-1+b2).
# libxext6 set to manually installed.
# The following additional packages will be installed:
#   i965-va-driver intel-media-va-driver libaacs0 libaom0 libasound2
#   libasound2-data libass9 libasyncns0 libavc1394-0 libavcodec58 libavdevice58
#   libavfilter7 libavformat58 libavresample4 libavutil56 libbdplus0 libbluray2
#   libbs2b0 libcaca0 libcap2 libcdio-cdda2 libcdio-paranoia2 libcdio18
#   libchromaprint1 libcodec2-0.8.1 libcrystalhd3 libdc1394-22 libdrm-amdgpu1
#   libdrm-common libdrm-intel1 libdrm-nouveau2 libdrm-radeon1 libdrm2
#   libfftw3-double3 libflac8 libflite1 libgl1 libgl1-mesa-dri libglapi-mesa
#   libglvnd0 libglx-mesa0 libglx0 libgme0 libgsm1 libiec61883-0 libigdgmm5
#   libjack-jackd2-0 liblilv-0-0 libllvm7 libmp3lame0 libmpg123-0 libmysofa0
#   libnorm1 libnuma1 libogg0 libopenal-data libopenal1 libopenjp2-7 libopenmpt0
#   libopus0 libpciaccess0 libpgm-5.2-0 libpostproc55 libpulse0 libraw1394-11
#   librubberband2 libsamplerate0 libsdl2-2.0-0 libsensors-config libsensors5
#   libserd-0-0 libshine3 libslang2 libsnappy1v5 libsndfile1 libsndio7.0
#   libsodium23 libsord-0-0 libsoxr0 libspeex1 libsratom-0-0 libssh-gcrypt-4
#   libswresample3 libswscale5 libtheora0 libtwolame0 libusb-1.0-0 libva-drm2
#   libva-x11-2 libva2 libvdpau-va-gl1 libvdpau1 libvidstab1.1 libvorbis0a
#   libvorbisenc2 libvorbisfile3 libvpx5 libwavpack1 libwayland-client0
#   libwayland-cursor0 libwayland-egl1 libwebpmux3 libx11-xcb1 libx264-155
#   libx265-165 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0 libxcb-present0
#   libxcb-shape0 libxcb-sync1 libxcb-xfixes0 libxkbcommon0 libxshmfence1
#   libxss1 libxtst6 libxv1 libxvidcore4 libxxf86vm1 libzmq5 libzvbi-common
#   libzvbi0 mesa-va-drivers mesa-vdpau-drivers va-driver-all vdpau-driver-all
#   xkb-data
# Suggested packages:
#   ffmpeg-doc i965-va-driver-shaders libasound2-plugins alsa-utils
#   libbluray-bdj firmware-crystalhd libfftw3-bin libfftw3-dev jackd2
#   libportaudio2 opus-tools pciutils pulseaudio libraw1394-doc lm-sensors serdi
#   sndiod sordi speex nvidia-vdpau-driver nvidia-legacy-340xx-vdpau-driver
#   nvidia-legacy-304xx-vdpau-driver
# The following NEW packages will be installed:
#   ffmpeg i965-va-driver intel-media-va-driver libaacs0 libaom0 libasound2
#   libasound2-data libass9 libasyncns0 libavc1394-0 libavcodec58 libavdevice58
#   libavfilter7 libavformat58 libavresample4 libavutil56 libbdplus0 libbluray2
#   libbs2b0 libcaca0 libcap2 libcdio-cdda2 libcdio-paranoia2 libcdio18
#   libchromaprint1 libcodec2-0.8.1 libcrystalhd3 libdc1394-22 libdrm-amdgpu1
#   libdrm-common libdrm-intel1 libdrm-nouveau2 libdrm-radeon1 libdrm2
#   libfftw3-double3 libflac8 libflite1 libgl1 libgl1-mesa-dri libglapi-mesa
#   libglvnd0 libglx-mesa0 libglx0 libgme0 libgsm1 libiec61883-0 libigdgmm5
#   libjack-jackd2-0 liblilv-0-0 libllvm7 libmp3lame0 libmpg123-0 libmysofa0
#   libnorm1 libnuma1 libogg0 libopenal-data libopenal1 libopenjp2-7 libopenmpt0
#   libopus0 libpciaccess0 libpgm-5.2-0 libpostproc55 libpulse0 libraw1394-11
#   librubberband2 libsamplerate0 libsdl2-2.0-0 libsensors-config libsensors5
#   libserd-0-0 libshine3 libslang2 libsnappy1v5 libsndfile1 libsndio7.0
#   libsodium23 libsord-0-0 libsoxr0 libspeex1 libsratom-0-0 libssh-gcrypt-4
#   libswresample3 libswscale5 libtheora0 libtwolame0 libusb-1.0-0 libva-drm2
#   libva-x11-2 libva2 libvdpau-va-gl1 libvdpau1 libvidstab1.1 libvorbis0a
#   libvorbisenc2 libvorbisfile3 libvpx5 libwavpack1 libwayland-client0
#   libwayland-cursor0 libwayland-egl1 libwebpmux3 libx11-xcb1 libx264-155
#   libx265-165 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0 libxcb-present0
#   libxcb-shape0 libxcb-sync1 libxcb-xfixes0 libxkbcommon0 libxshmfence1
#   libxss1 libxtst6 libxv1 libxvidcore4 libxxf86vm1 libzmq5 libzvbi-common
#   libzvbi0 mesa-va-drivers mesa-vdpau-drivers va-driver-all vdpau-driver-all
#   xkb-data
# 0 upgraded, 128 newly installed, 0 to remove and 2 not upgraded.
# Need to get 64.3 MB of archives.
# After this operation, 380 MB of additional disk space will be used.
# Get:1 http://security.debian.org/debian-security buster/updates/main amd64 libavutil56 amd64 7:4.1.8-0+deb10u1 [243 kB]
# Get:2 http://deb.debian.org/debian buster/main amd64 libaom0 amd64 1.0.0-3 [1,165 kB]
# Get:3 http://security.debian.org/debian-security buster/updates/main amd64 libswresample3 amd64 7:4.1.8-0+deb10u1 [111 kB]
# Get:4 http://security.debian.org/debian-security buster/updates/main amd64 libavcodec58 amd64 7:4.1.8-0+deb10u1 [4,809 kB]
# Get:5 http://deb.debian.org/debian buster/main amd64 libdrm-common all 2.4.97-1 [13.8 kB]
# Get:6 http://deb.debian.org/debian buster/main amd64 libdrm2 amd64 2.4.97-1 [39.7 kB]
# Get:7 http://deb.debian.org/debian buster/main amd64 libva2 amd64 2.4.0-1 [57.2 kB]
# Get:8 http://deb.debian.org/debian buster/main amd64 libva-drm2 amd64 2.4.0-1 [16.6 kB]
# Get:9 http://deb.debian.org/debian buster/main amd64 libva-x11-2 amd64 2.4.0-1 [21.3 kB]
# Get:10 http://deb.debian.org/debian buster/main amd64 libvdpau1 amd64 1.1.1-10 [42.0 kB]
# Get:11 http://deb.debian.org/debian buster/main amd64 libcodec2-0.8.1 amd64 0.8.1-2 [233 kB]
# Get:12 http://deb.debian.org/debian buster/main amd64 libcrystalhd3 amd64 1:0.0~git20110715.fdd2f19-13 [45.9 kB]
# Get:13 http://deb.debian.org/debian buster/main amd64 libgsm1 amd64 1.0.18-2 [27.7 kB]
# Get:14 http://deb.debian.org/debian buster/main amd64 libmp3lame0 amd64 3.100-2+b1 [367 kB]
# Get:15 http://deb.debian.org/debian buster/main amd64 libopenjp2-7 amd64 2.3.0-2+deb10u2 [158 kB]
# Get:16 http://deb.debian.org/debian buster/main amd64 libopus0 amd64 1.3-1 [191 kB]
# Get:17 http://deb.debian.org/debian buster/main amd64 libshine3 amd64 3.1.1-2 [23.6 kB]
# Get:18 http://deb.debian.org/debian buster/main amd64 libsnappy1v5 amd64 1.1.7-1 [17.0 kB]
# Get:19 http://deb.debian.org/debian buster/main amd64 libspeex1 amd64 1.2~rc1.2-1+b2 [54.8 kB]
# Get:20 http://deb.debian.org/debian buster/main amd64 libsoxr0 amd64 0.1.2-3 [65.9 kB]
# Get:21 http://deb.debian.org/debian buster/main amd64 libogg0 amd64 1.3.2-1+b1 [21.3 kB]
# Get:22 http://deb.debian.org/debian buster/main amd64 libtheora0 amd64 1.1.1+dfsg.1-15 [169 kB]
# Get:23 http://deb.debian.org/debian buster/main amd64 libtwolame0 amd64 0.3.13-4 [49.3 kB]
# Get:24 http://deb.debian.org/debian buster/main amd64 libvorbis0a amd64 1.3.6-2 [93.5 kB]
# Get:25 http://deb.debian.org/debian buster/main amd64 libvorbisenc2 amd64 1.3.6-2 [80.2 kB]
# Get:26 http://deb.debian.org/debian buster/main amd64 libvpx5 amd64 1.7.0-3+deb10u1 [800 kB]
# Get:27 http://deb.debian.org/debian buster/main amd64 libwavpack1 amd64 5.1.0-6 [86.8 kB]
# Get:28 http://deb.debian.org/debian buster/main amd64 libwebpmux3 amd64 0.6.1-2+deb10u1 [97.8 kB]
# Get:29 http://deb.debian.org/debian buster/main amd64 libx264-155 amd64 2:0.155.2917+git0a84d98-2 [528 kB]
# Get:30 http://deb.debian.org/debian buster/main amd64 libnuma1 amd64 2.0.12-1 [26.2 kB]
# Get:31 http://deb.debian.org/debian buster/main amd64 libx265-165 amd64 2.9-4 [1,041 kB]
# Get:32 http://security.debian.org/debian-security buster/updates/main amd64 libavformat58 amd64 7:4.1.8-0+deb10u1 [1,018 kB]
# Get:33 http://security.debian.org/debian-security buster/updates/main amd64 libpostproc55 amd64 7:4.1.8-0+deb10u1 [107 kB]
# Get:34 http://deb.debian.org/debian buster/main amd64 libxvidcore4 amd64 2:1.3.5-1 [241 kB]
# Get:35 http://security.debian.org/debian-security buster/updates/main amd64 libswscale5 amd64 7:4.1.8-0+deb10u1 [208 kB]
# Get:36 http://deb.debian.org/debian buster/main amd64 libzvbi-common all 0.2.35-16 [64.3 kB]
# Get:37 http://security.debian.org/debian-security buster/updates/main amd64 libavfilter7 amd64 7:4.1.8-0+deb10u1 [1,053 kB]
# Get:38 http://deb.debian.org/debian buster/main amd64 libzvbi0 amd64 0.2.35-16 [270 kB]
# Get:39 http://deb.debian.org/debian buster/main amd64 libasound2-data all 1.1.8-1 [59.6 kB]
# Get:40 http://deb.debian.org/debian buster/main amd64 libasound2 amd64 1.1.8-1 [361 kB]
# Get:41 http://deb.debian.org/debian buster/main amd64 libraw1394-11 amd64 2.1.2-1+b1 [47.2 kB]
# Get:42 http://deb.debian.org/debian buster/main amd64 libavc1394-0 amd64 0.5.4-5 [19.9 kB]
# Get:43 http://deb.debian.org/debian buster/main amd64 libass9 amd64 1:0.14.0-2 [96.7 kB]
# Get:44 http://deb.debian.org/debian buster/main amd64 libbluray2 amd64 1:1.1.0-1 [145 kB]
# Get:45 http://security.debian.org/debian-security buster/updates/main amd64 libavdevice58 amd64 7:4.1.8-0+deb10u1 [129 kB]
# Get:46 http://deb.debian.org/debian buster/main amd64 libchromaprint1 amd64 1.4.3-3 [41.4 kB]
# Get:47 http://security.debian.org/debian-security buster/updates/main amd64 libavresample4 amd64 7:4.1.8-0+deb10u1 [108 kB]
# Get:48 http://deb.debian.org/debian buster/main amd64 libgme0 amd64 0.6.2-1 [121 kB]
# Get:49 http://security.debian.org/debian-security buster/updates/main amd64 ffmpeg amd64 7:4.1.8-0+deb10u1 [1,440 kB]
# Get:50 http://deb.debian.org/debian buster/main amd64 libmpg123-0 amd64 1.25.10-2 [140 kB]
# Get:51 http://deb.debian.org/debian buster/main amd64 libvorbisfile3 amd64 1.3.6-2 [25.5 kB]
# Get:52 http://deb.debian.org/debian buster/main amd64 libopenmpt0 amd64 0.4.3-1+deb10u1 [627 kB]
# Get:53 http://deb.debian.org/debian buster/main amd64 libssh-gcrypt-4 amd64 0.8.7-1+deb10u1 [200 kB]
# Get:54 http://deb.debian.org/debian buster/main amd64 libbs2b0 amd64 3.1.0+dfsg-2.2 [12.2 kB]
# Get:55 http://deb.debian.org/debian buster/main amd64 libflite1 amd64 2.1-release-3 [12.8 MB]
# Get:56 http://deb.debian.org/debian buster/main amd64 libserd-0-0 amd64 0.28.0~dfsg0-1 [40.8 kB]
# Get:57 http://deb.debian.org/debian buster/main amd64 libsord-0-0 amd64 0.16.0~dfsg0-1+b1 [23.0 kB]
# Get:58 http://deb.debian.org/debian buster/main amd64 libsratom-0-0 amd64 0.6.0~dfsg0-1 [16.6 kB]
# Get:59 http://deb.debian.org/debian buster/main amd64 liblilv-0-0 amd64 0.24.2~dfsg0-2 [44.2 kB]
# Get:60 http://deb.debian.org/debian buster/main amd64 libmysofa0 amd64 0.6~dfsg0-3+deb10u1 [38.2 kB]
# Get:61 http://deb.debian.org/debian buster/main amd64 libfftw3-double3 amd64 3.3.8-2 [733 kB]
# Get:62 http://deb.debian.org/debian buster/main amd64 libsamplerate0 amd64 0.1.9-2 [949 kB]
# Get:63 http://deb.debian.org/debian buster/main amd64 librubberband2 amd64 1.8.1-7 [86.0 kB]
# Get:64 http://deb.debian.org/debian buster/main amd64 libvidstab1.1 amd64 1.1.0-2 [37.6 kB]
# Get:65 http://deb.debian.org/debian buster/main amd64 libnorm1 amd64 1.5.8+dfsg2-1 [287 kB]
# Get:66 http://deb.debian.org/debian buster/main amd64 libpgm-5.2-0 amd64 5.2.122~dfsg-3 [158 kB]
# Get:67 http://deb.debian.org/debian buster/main amd64 libsodium23 amd64 1.0.17-1 [158 kB]
# Get:68 http://deb.debian.org/debian buster/main amd64 libzmq5 amd64 4.3.1-4+deb10u2 [246 kB]
# Get:69 http://deb.debian.org/debian buster/main amd64 libslang2 amd64 2.3.2-2 [507 kB]
# Get:70 http://deb.debian.org/debian buster/main amd64 libcaca0 amd64 0.99.beta19-2.1 [346 kB]
# Get:71 http://deb.debian.org/debian buster/main amd64 libcdio18 amd64 2.0.0-2 [199 kB]
# Get:72 http://deb.debian.org/debian buster/main amd64 libcdio-cdda2 amd64 10.2+0.94+2-4 [26.4 kB]
# Get:73 http://deb.debian.org/debian buster/main amd64 libcdio-paranoia2 amd64 10.2+0.94+2-4 [27.8 kB]
# Get:74 http://deb.debian.org/debian buster/main amd64 libusb-1.0-0 amd64 2:1.0.22-2 [55.3 kB]
# Get:75 http://deb.debian.org/debian buster/main amd64 libdc1394-22 amd64 2.2.5-1 [106 kB]
# Get:76 http://deb.debian.org/debian buster/main amd64 libglvnd0 amd64 1.1.0-1 [48.6 kB]
# Get:77 http://deb.debian.org/debian buster/main amd64 libglapi-mesa amd64 18.3.6-2+deb10u1 [66.3 kB]
# Get:78 http://deb.debian.org/debian buster/main amd64 libx11-xcb1 amd64 2:1.6.7-1+deb10u2 [191 kB]
# Get:79 http://deb.debian.org/debian buster/main amd64 libxcb-dri2-0 amd64 1.13.1-2 [101 kB]
# Get:80 http://deb.debian.org/debian buster/main amd64 libxcb-dri3-0 amd64 1.13.1-2 [100 kB]
# Get:81 http://deb.debian.org/debian buster/main amd64 libxcb-glx0 amd64 1.13.1-2 [116 kB]
# Get:82 http://deb.debian.org/debian buster/main amd64 libxcb-present0 amd64 1.13.1-2 [99.1 kB]
# Get:83 http://deb.debian.org/debian buster/main amd64 libxcb-sync1 amd64 1.13.1-2 [103 kB]
# Get:84 http://deb.debian.org/debian buster/main amd64 libxshmfence1 amd64 1.3-1 [8,820 B]
# Get:85 http://deb.debian.org/debian buster/main amd64 libxxf86vm1 amd64 1:1.1.4-1+b2 [20.8 kB]
# Get:86 http://deb.debian.org/debian buster/main amd64 libdrm-amdgpu1 amd64 2.4.97-1 [27.3 kB]
# Get:87 http://deb.debian.org/debian buster/main amd64 libpciaccess0 amd64 0.14-1 [53.5 kB]
# Get:88 http://deb.debian.org/debian buster/main amd64 libdrm-intel1 amd64 2.4.97-1 [69.8 kB]
# Get:89 http://deb.debian.org/debian buster/main amd64 libdrm-nouveau2 amd64 2.4.97-1 [26.3 kB]
# Get:90 http://deb.debian.org/debian buster/main amd64 libdrm-radeon1 amd64 2.4.97-1 [31.1 kB]
# Get:91 http://deb.debian.org/debian buster/main amd64 libllvm7 amd64 1:7.0.1-8+deb10u2 [13.1 MB]
# Get:92 http://deb.debian.org/debian buster/main amd64 libsensors-config all 1:3.5.0-3 [31.6 kB]
# Get:93 http://deb.debian.org/debian buster/main amd64 libsensors5 amd64 1:3.5.0-3 [52.6 kB]
# Get:94 http://deb.debian.org/debian buster/main amd64 libgl1-mesa-dri amd64 18.3.6-2+deb10u1 [6,685 kB]
# Get:95 http://deb.debian.org/debian buster/main amd64 libglx-mesa0 amd64 18.3.6-2+deb10u1 [180 kB]
# Get:96 http://deb.debian.org/debian buster/main amd64 libglx0 amd64 1.1.0-1 [30.0 kB]
# Get:97 http://deb.debian.org/debian buster/main amd64 libgl1 amd64 1.1.0-1 [91.1 kB]
# Get:98 http://deb.debian.org/debian buster/main amd64 libiec61883-0 amd64 1.2.0-3 [31.2 kB]
# Get:99 http://deb.debian.org/debian buster/main amd64 libjack-jackd2-0 amd64 1.9.12~dfsg-2 [299 kB]
# Get:100 http://deb.debian.org/debian buster/main amd64 libopenal-data all 1:1.19.1-1 [170 kB]
# Get:101 http://deb.debian.org/debian buster/main amd64 libsndio7.0 amd64 1.5.0-3 [24.7 kB]
# Get:102 http://deb.debian.org/debian buster/main amd64 libopenal1 amd64 1:1.19.1-1 [500 kB]
# Get:103 http://deb.debian.org/debian buster/main amd64 libasyncns0 amd64 0.8-6 [12.5 kB]
# Get:104 http://deb.debian.org/debian buster/main amd64 libcap2 amd64 1:2.25-2 [17.6 kB]
# Get:105 http://deb.debian.org/debian buster/main amd64 libflac8 amd64 1.3.2-3 [221 kB]
# Get:106 http://deb.debian.org/debian buster/main amd64 libsndfile1 amd64 1.0.28-6+deb10u1 [253 kB]
# Get:107 http://deb.debian.org/debian buster/main amd64 libxtst6 amd64 2:1.2.3-1 [27.8 kB]
# Get:108 http://deb.debian.org/debian buster/main amd64 libpulse0 amd64 12.2-4+deb10u1 [281 kB]
# Get:109 http://deb.debian.org/debian buster/main amd64 libwayland-client0 amd64 1.16.0-1 [26.4 kB]
# Get:110 http://deb.debian.org/debian buster/main amd64 libwayland-cursor0 amd64 1.16.0-1 [14.1 kB]
# Get:111 http://deb.debian.org/debian buster/main amd64 libwayland-egl1 amd64 1.16.0-1 [8,204 B]
# Get:112 http://deb.debian.org/debian buster/main amd64 xkb-data all 2.26-2 [681 kB]
# Get:113 http://deb.debian.org/debian buster/main amd64 libxkbcommon0 amd64 0.8.2-1 [123 kB]
# Get:114 http://deb.debian.org/debian buster/main amd64 libxss1 amd64 1:1.2.3-1 [17.8 kB]
# Get:115 http://deb.debian.org/debian buster/main amd64 libsdl2-2.0-0 amd64 2.0.9+dfsg1-1 [401 kB]
# Get:116 http://deb.debian.org/debian buster/main amd64 libxcb-shape0 amd64 1.13.1-2 [99.5 kB]
# Get:117 http://deb.debian.org/debian buster/main amd64 libxcb-xfixes0 amd64 1.13.1-2 [103 kB]
# Get:118 http://deb.debian.org/debian buster/main amd64 libxv1 amd64 2:1.0.11-1 [24.6 kB]
# Get:119 http://deb.debian.org/debian buster/main amd64 i965-va-driver amd64 2.3.0+dfsg1-1 [311 kB]
# Get:120 http://deb.debian.org/debian buster/main amd64 libigdgmm5 amd64 18.4.1+ds1-1 [78.7 kB]
# Get:121 http://deb.debian.org/debian buster/main amd64 intel-media-va-driver amd64 18.4.1+dfsg1-1 [974 kB]
# Get:122 http://deb.debian.org/debian buster/main amd64 libaacs0 amd64 0.9.0-2 [52.4 kB]
# Get:123 http://deb.debian.org/debian buster/main amd64 libbdplus0 amd64 0.1.2-3 [47.5 kB]
# Get:124 http://deb.debian.org/debian buster/main amd64 libvdpau-va-gl1 amd64 0.4.2-1+b1 [71.3 kB]
# Get:125 http://deb.debian.org/debian buster/main amd64 mesa-va-drivers amd64 18.3.6-2+deb10u1 [1,972 kB]
# Get:126 http://deb.debian.org/debian buster/main amd64 mesa-vdpau-drivers amd64 18.3.6-2+deb10u1 [2,101 kB]
# Get:127 http://deb.debian.org/debian buster/main amd64 va-driver-all amd64 2.4.0-1 [13.0 kB]
# Get:128 http://deb.debian.org/debian buster/main amd64 vdpau-driver-all amd64 1.1.1-10 [20.8 kB]
# Fetched 64.3 MB in 2s (38.2 MB/s)
# debconf: delaying package configuration, since apt-utils is not installed
#
# 78Selecting previously unselected package libaom0:amd64.
# (Reading database ... 31086 files and directories currently installed.)
# Preparing to unpack .../000-libaom0_1.0.0-3_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 8Unpacking libaom0:amd64 (1.0.0-3) ...
# Selecting previously unselected package libdrm-common.
# Preparing to unpack .../001-libdrm-common_2.4.97-1_all.deb ...
# Unpacking libdrm-common (2.4.97-1) ...
# Selecting previously unselected package libdrm2:amd64.
# Preparing to unpack .../002-libdrm2_2.4.97-1_amd64.deb ...
# Unpacking libdrm2:amd64 (2.4.97-1) ...
# 7Progress: [  1%] [..........................................................] 8Selecting previously unselected package libva2:amd64.
# Preparing to unpack .../003-libva2_2.4.0-1_amd64.deb ...
# Unpacking libva2:amd64 (2.4.0-1) ...
# Selecting previously unselected package libva-drm2:amd64.
# Preparing to unpack .../004-libva-drm2_2.4.0-1_amd64.deb ...
# Unpacking libva-drm2:amd64 (2.4.0-1) ...
# Selecting previously unselected package libva-x11-2:amd64.
# Preparing to unpack .../005-libva-x11-2_2.4.0-1_amd64.deb ...
# 7Progress: [  2%] [#.........................................................] 8Unpacking libva-x11-2:amd64 (2.4.0-1) ...
# Selecting previously unselected package libvdpau1:amd64.
# Preparing to unpack .../006-libvdpau1_1.1.1-10_amd64.deb ...
# Unpacking libvdpau1:amd64 (1.1.1-10) ...
# Selecting previously unselected package libavutil56:amd64.
# Preparing to unpack .../007-libavutil56_7%3a4.1.8-0+deb10u1_amd64.deb ...
# Unpacking libavutil56:amd64 (7:4.1.8-0+deb10u1) ...
# 7Progress: [  3%] [#.........................................................] 8Selecting previously unselected package libcodec2-0.8.1:amd64.
# Preparing to unpack .../008-libcodec2-0.8.1_0.8.1-2_amd64.deb ...
# Unpacking libcodec2-0.8.1:amd64 (0.8.1-2) ...
# Selecting previously unselected package libcrystalhd3:amd64.
# Preparing to unpack .../009-libcrystalhd3_1%3a0.0~git20110715.fdd2f19-13_amd64.deb ...
# Unpacking libcrystalhd3:amd64 (1:0.0~git20110715.fdd2f19-13) ...
# Selecting previously unselected package libgsm1:amd64.
# Preparing to unpack .../010-libgsm1_1.0.18-2_amd64.deb ...
# 7Progress: [  4%] [##........................................................] 8Unpacking libgsm1:amd64 (1.0.18-2) ...
# Selecting previously unselected package libmp3lame0:amd64.
# Preparing to unpack .../011-libmp3lame0_3.100-2+b1_amd64.deb ...
# Unpacking libmp3lame0:amd64 (3.100-2+b1) ...
# Selecting previously unselected package libopenjp2-7:amd64.
# Preparing to unpack .../012-libopenjp2-7_2.3.0-2+deb10u2_amd64.deb ...
# Unpacking libopenjp2-7:amd64 (2.3.0-2+deb10u2) ...
# 7Progress: [  5%] [##........................................................] 8Selecting previously unselected package libopus0:amd64.
# Preparing to unpack .../013-libopus0_1.3-1_amd64.deb ...
# Unpacking libopus0:amd64 (1.3-1) ...
# Selecting previously unselected package libshine3:amd64.
# Preparing to unpack .../014-libshine3_3.1.1-2_amd64.deb ...
# Unpacking libshine3:amd64 (3.1.1-2) ...
# Selecting previously unselected package libsnappy1v5:amd64.
# Preparing to unpack .../015-libsnappy1v5_1.1.7-1_amd64.deb ...
# 7Progress: [  6%] [###.......................................................] 8Unpacking libsnappy1v5:amd64 (1.1.7-1) ...
# Selecting previously unselected package libspeex1:amd64.
# Preparing to unpack .../016-libspeex1_1.2~rc1.2-1+b2_amd64.deb ...
# Unpacking libspeex1:amd64 (1.2~rc1.2-1+b2) ...
# Selecting previously unselected package libsoxr0:amd64.
# Preparing to unpack .../017-libsoxr0_0.1.2-3_amd64.deb ...
# Unpacking libsoxr0:amd64 (0.1.2-3) ...
# 7Progress: [  7%] [####......................................................] 8Selecting previously unselected package libswresample3:amd64.
# Preparing to unpack .../018-libswresample3_7%3a4.1.8-0+deb10u1_amd64.deb ...
# Unpacking libswresample3:amd64 (7:4.1.8-0+deb10u1) ...
# Selecting previously unselected package libogg0:amd64.
# Preparing to unpack .../019-libogg0_1.3.2-1+b1_amd64.deb ...
# Unpacking libogg0:amd64 (1.3.2-1+b1) ...
# Selecting previously unselected package libtheora0:amd64.
# Preparing to unpack .../020-libtheora0_1.1.1+dfsg.1-15_amd64.deb ...
# Unpacking libtheora0:amd64 (1.1.1+dfsg.1-15) ...
# 7Progress: [  8%] [####......................................................] 8Selecting previously unselected package libtwolame0:amd64.
# Preparing to unpack .../021-libtwolame0_0.3.13-4_amd64.deb ...
# Unpacking libtwolame0:amd64 (0.3.13-4) ...
# Selecting previously unselected package libvorbis0a:amd64.
# Preparing to unpack .../022-libvorbis0a_1.3.6-2_amd64.deb ...
# Unpacking libvorbis0a:amd64 (1.3.6-2) ...
# Selecting previously unselected package libvorbisenc2:amd64.
# Preparing to unpack .../023-libvorbisenc2_1.3.6-2_amd64.deb ...
# 7Progress: [  9%] [#####.....................................................] 8Unpacking libvorbisenc2:amd64 (1.3.6-2) ...
# Selecting previously unselected package libvpx5:amd64.
# Preparing to unpack .../024-libvpx5_1.7.0-3+deb10u1_amd64.deb ...
# Unpacking libvpx5:amd64 (1.7.0-3+deb10u1) ...
# Selecting previously unselected package libwavpack1:amd64.
# Preparing to unpack .../025-libwavpack1_5.1.0-6_amd64.deb ...
# Unpacking libwavpack1:amd64 (5.1.0-6) ...
# 7Progress: [ 10%] [#####.....................................................] 8Selecting previously unselected package libwebpmux3:amd64.
# Preparing to unpack .../026-libwebpmux3_0.6.1-2+deb10u1_amd64.deb ...
# Unpacking libwebpmux3:amd64 (0.6.1-2+deb10u1) ...
# Selecting previously unselected package libx264-155:amd64.
# Preparing to unpack .../027-libx264-155_2%3a0.155.2917+git0a84d98-2_amd64.deb ...
# Unpacking libx264-155:amd64 (2:0.155.2917+git0a84d98-2) ...
# Selecting previously unselected package libnuma1:amd64.
# Preparing to unpack .../028-libnuma1_2.0.12-1_amd64.deb ...
# 7Progress: [ 11%] [######....................................................] 8Unpacking libnuma1:amd64 (2.0.12-1) ...
# Selecting previously unselected package libx265-165:amd64.
# Preparing to unpack .../029-libx265-165_2.9-4_amd64.deb ...
# Unpacking libx265-165:amd64 (2.9-4) ...
# Selecting previously unselected package libxvidcore4:amd64.
# Preparing to unpack .../030-libxvidcore4_2%3a1.3.5-1_amd64.deb ...
# Unpacking libxvidcore4:amd64 (2:1.3.5-1) ...
# 7Progress: [ 12%] [#######...................................................] 8Selecting previously unselected package libzvbi-common.
# Preparing to unpack .../031-libzvbi-common_0.2.35-16_all.deb ...
# Unpacking libzvbi-common (0.2.35-16) ...
# Selecting previously unselected package libzvbi0:amd64.
# Preparing to unpack .../032-libzvbi0_0.2.35-16_amd64.deb ...
# Unpacking libzvbi0:amd64 (0.2.35-16) ...
# Selecting previously unselected package libavcodec58:amd64.
# Preparing to unpack .../033-libavcodec58_7%3a4.1.8-0+deb10u1_amd64.deb ...
# 7Progress: [ 13%] [#######...................................................] 8Unpacking libavcodec58:amd64 (7:4.1.8-0+deb10u1) ...
# Selecting previously unselected package libasound2-data.
# Preparing to unpack .../034-libasound2-data_1.1.8-1_all.deb ...
# Unpacking libasound2-data (1.1.8-1) ...
# Selecting previously unselected package libasound2:amd64.
# Preparing to unpack .../035-libasound2_1.1.8-1_amd64.deb ...
# Unpacking libasound2:amd64 (1.1.8-1) ...
# 7Progress: [ 14%] [########..................................................] 8Selecting previously unselected package libraw1394-11:amd64.
# Preparing to unpack .../036-libraw1394-11_2.1.2-1+b1_amd64.deb ...
# Unpacking libraw1394-11:amd64 (2.1.2-1+b1) ...
# Selecting previously unselected package libavc1394-0:amd64.
# Preparing to unpack .../037-libavc1394-0_0.5.4-5_amd64.deb ...
# Unpacking libavc1394-0:amd64 (0.5.4-5) ...
# Selecting previously unselected package libass9:amd64.
# Preparing to unpack .../038-libass9_1%3a0.14.0-2_amd64.deb ...
# 7Progress: [ 15%] [########..................................................] 8Unpacking libass9:amd64 (1:0.14.0-2) ...
# Selecting previously unselected package libbluray2:amd64.
# Preparing to unpack .../039-libbluray2_1%3a1.1.0-1_amd64.deb ...
# Unpacking libbluray2:amd64 (1:1.1.0-1) ...
# Selecting previously unselected package libchromaprint1:amd64.
# Preparing to unpack .../040-libchromaprint1_1.4.3-3_amd64.deb ...
# Unpacking libchromaprint1:amd64 (1.4.3-3) ...
# Selecting previously unselected package libgme0:amd64.
# Preparing to unpack .../041-libgme0_0.6.2-1_amd64.deb ...
# 7Progress: [ 16%] [#########.................................................] 8Unpacking libgme0:amd64 (0.6.2-1) ...
# Selecting previously unselected package libmpg123-0:amd64.
# Preparing to unpack .../042-libmpg123-0_1.25.10-2_amd64.deb ...
# Unpacking libmpg123-0:amd64 (1.25.10-2) ...
# Selecting previously unselected package libvorbisfile3:amd64.
# Preparing to unpack .../043-libvorbisfile3_1.3.6-2_amd64.deb ...
# Unpacking libvorbisfile3:amd64 (1.3.6-2) ...
# 7Progress: [ 17%] [#########.................................................] 8Selecting previously unselected package libopenmpt0:amd64.
# Preparing to unpack .../044-libopenmpt0_0.4.3-1+deb10u1_amd64.deb ...
# Unpacking libopenmpt0:amd64 (0.4.3-1+deb10u1) ...
# Selecting previously unselected package libssh-gcrypt-4:amd64.
# Preparing to unpack .../045-libssh-gcrypt-4_0.8.7-1+deb10u1_amd64.deb ...
# Unpacking libssh-gcrypt-4:amd64 (0.8.7-1+deb10u1) ...
# Selecting previously unselected package libavformat58:amd64.
# Preparing to unpack .../046-libavformat58_7%3a4.1.8-0+deb10u1_amd64.deb ...
# 7Progress: [ 18%] [##########................................................] 8Unpacking libavformat58:amd64 (7:4.1.8-0+deb10u1) ...
# Selecting previously unselected package libbs2b0:amd64.
# Preparing to unpack .../047-libbs2b0_3.1.0+dfsg-2.2_amd64.deb ...
# Unpacking libbs2b0:amd64 (3.1.0+dfsg-2.2) ...
# Selecting previously unselected package libflite1:amd64.
# Preparing to unpack .../048-libflite1_2.1-release-3_amd64.deb ...
# Unpacking libflite1:amd64 (2.1-release-3) ...
# 7Progress: [ 19%] [###########...............................................] 8Selecting previously unselected package libserd-0-0:amd64.
# Preparing to unpack .../049-libserd-0-0_0.28.0~dfsg0-1_amd64.deb ...
# Unpacking libserd-0-0:amd64 (0.28.0~dfsg0-1) ...
# Selecting previously unselected package libsord-0-0:amd64.
# Preparing to unpack .../050-libsord-0-0_0.16.0~dfsg0-1+b1_amd64.deb ...
# Unpacking libsord-0-0:amd64 (0.16.0~dfsg0-1+b1) ...
# Selecting previously unselected package libsratom-0-0:amd64.
# Preparing to unpack .../051-libsratom-0-0_0.6.0~dfsg0-1_amd64.deb ...
# 7Progress: [ 20%] [###########...............................................] 8Unpacking libsratom-0-0:amd64 (0.6.0~dfsg0-1) ...
# Selecting previously unselected package liblilv-0-0:amd64.
# Preparing to unpack .../052-liblilv-0-0_0.24.2~dfsg0-2_amd64.deb ...
# Unpacking liblilv-0-0:amd64 (0.24.2~dfsg0-2) ...
# Selecting previously unselected package libmysofa0:amd64.
# Preparing to unpack .../053-libmysofa0_0.6~dfsg0-3+deb10u1_amd64.deb ...
# Unpacking libmysofa0:amd64 (0.6~dfsg0-3+deb10u1) ...
# 7Progress: [ 21%] [############..............................................] 8Selecting previously unselected package libpostproc55:amd64.
# Preparing to unpack .../054-libpostproc55_7%3a4.1.8-0+deb10u1_amd64.deb ...
# Unpacking libpostproc55:amd64 (7:4.1.8-0+deb10u1) ...
# Selecting previously unselected package libfftw3-double3:amd64.
# Preparing to unpack .../055-libfftw3-double3_3.3.8-2_amd64.deb ...
# Unpacking libfftw3-double3:amd64 (3.3.8-2) ...
# Selecting previously unselected package libsamplerate0:amd64.
# Preparing to unpack .../056-libsamplerate0_0.1.9-2_amd64.deb ...
# 7Progress: [ 22%] [############..............................................] 8Unpacking libsamplerate0:amd64 (0.1.9-2) ...
# Selecting previously unselected package librubberband2:amd64.
# Preparing to unpack .../057-librubberband2_1.8.1-7_amd64.deb ...
# Unpacking librubberband2:amd64 (1.8.1-7) ...
# Selecting previously unselected package libswscale5:amd64.
# Preparing to unpack .../058-libswscale5_7%3a4.1.8-0+deb10u1_amd64.deb ...
# Unpacking libswscale5:amd64 (7:4.1.8-0+deb10u1) ...
# 7Progress: [ 23%] [#############.............................................] 8Selecting previously unselected package libvidstab1.1:amd64.
# Preparing to unpack .../059-libvidstab1.1_1.1.0-2_amd64.deb ...
# Unpacking libvidstab1.1:amd64 (1.1.0-2) ...
# Selecting previously unselected package libnorm1:amd64.
# Preparing to unpack .../060-libnorm1_1.5.8+dfsg2-1_amd64.deb ...
# Unpacking libnorm1:amd64 (1.5.8+dfsg2-1) ...
# Selecting previously unselected package libpgm-5.2-0:amd64.
# Preparing to unpack .../061-libpgm-5.2-0_5.2.122~dfsg-3_amd64.deb ...
# Unpacking libpgm-5.2-0:amd64 (5.2.122~dfsg-3) ...
# 7Progress: [ 24%] [##############............................................] 8Selecting previously unselected package libsodium23:amd64.
# Preparing to unpack .../062-libsodium23_1.0.17-1_amd64.deb ...
# Unpacking libsodium23:amd64 (1.0.17-1) ...
# Selecting previously unselected package libzmq5:amd64.
# Preparing to unpack .../063-libzmq5_4.3.1-4+deb10u2_amd64.deb ...
# Unpacking libzmq5:amd64 (4.3.1-4+deb10u2) ...
# Selecting previously unselected package libavfilter7:amd64.
# Preparing to unpack .../064-libavfilter7_7%3a4.1.8-0+deb10u1_amd64.deb ...
# 7Progress: [ 25%] [##############............................................] 8Unpacking libavfilter7:amd64 (7:4.1.8-0+deb10u1) ...
# Selecting previously unselected package libslang2:amd64.
# Preparing to unpack .../065-libslang2_2.3.2-2_amd64.deb ...
# Unpacking libslang2:amd64 (2.3.2-2) ...
# Selecting previously unselected package libcaca0:amd64.
# Preparing to unpack .../066-libcaca0_0.99.beta19-2.1_amd64.deb ...
# Unpacking libcaca0:amd64 (0.99.beta19-2.1) ...
# 7Progress: [ 26%] [###############...........................................] 8Selecting previously unselected package libcdio18:amd64.
# Preparing to unpack .../067-libcdio18_2.0.0-2_amd64.deb ...
# Unpacking libcdio18:amd64 (2.0.0-2) ...
# Selecting previously unselected package libcdio-cdda2:amd64.
# Preparing to unpack .../068-libcdio-cdda2_10.2+0.94+2-4_amd64.deb ...
# Unpacking libcdio-cdda2:amd64 (10.2+0.94+2-4) ...
# Selecting previously unselected package libcdio-paranoia2:amd64.
# Preparing to unpack .../069-libcdio-paranoia2_10.2+0.94+2-4_amd64.deb ...
# 7Progress: [ 27%] [###############...........................................] 8Unpacking libcdio-paranoia2:amd64 (10.2+0.94+2-4) ...
# Selecting previously unselected package libusb-1.0-0:amd64.
# Preparing to unpack .../070-libusb-1.0-0_2%3a1.0.22-2_amd64.deb ...
# Unpacking libusb-1.0-0:amd64 (2:1.0.22-2) ...
# Selecting previously unselected package libdc1394-22:amd64.
# Preparing to unpack .../071-libdc1394-22_2.2.5-1_amd64.deb ...
# Unpacking libdc1394-22:amd64 (2.2.5-1) ...
# 7Progress: [ 28%] [################..........................................] 8Selecting previously unselected package libglvnd0:amd64.
# Preparing to unpack .../072-libglvnd0_1.1.0-1_amd64.deb ...
# Unpacking libglvnd0:amd64 (1.1.0-1) ...
# Selecting previously unselected package libglapi-mesa:amd64.
# Preparing to unpack .../073-libglapi-mesa_18.3.6-2+deb10u1_amd64.deb ...
# Unpacking libglapi-mesa:amd64 (18.3.6-2+deb10u1) ...
# Selecting previously unselected package libx11-xcb1:amd64.
# Preparing to unpack .../074-libx11-xcb1_2%3a1.6.7-1+deb10u2_amd64.deb ...
# 7Progress: [ 29%] [################..........................................] 8Unpacking libx11-xcb1:amd64 (2:1.6.7-1+deb10u2) ...
# Selecting previously unselected package libxcb-dri2-0:amd64.
# Preparing to unpack .../075-libxcb-dri2-0_1.13.1-2_amd64.deb ...
# Unpacking libxcb-dri2-0:amd64 (1.13.1-2) ...
# Selecting previously unselected package libxcb-dri3-0:amd64.
# Preparing to unpack .../076-libxcb-dri3-0_1.13.1-2_amd64.deb ...
# Unpacking libxcb-dri3-0:amd64 (1.13.1-2) ...
# 7Progress: [ 30%] [#################.........................................] 8Selecting previously unselected package libxcb-glx0:amd64.
# Preparing to unpack .../077-libxcb-glx0_1.13.1-2_amd64.deb ...
# Unpacking libxcb-glx0:amd64 (1.13.1-2) ...
# Selecting previously unselected package libxcb-present0:amd64.
# Preparing to unpack .../078-libxcb-present0_1.13.1-2_amd64.deb ...
# Unpacking libxcb-present0:amd64 (1.13.1-2) ...
# Selecting previously unselected package libxcb-sync1:amd64.
# Preparing to unpack .../079-libxcb-sync1_1.13.1-2_amd64.deb ...
# Unpacking libxcb-sync1:amd64 (1.13.1-2) ...
# 7Progress: [ 31%] [##################........................................] 8Selecting previously unselected package libxshmfence1:amd64.
# Preparing to unpack .../080-libxshmfence1_1.3-1_amd64.deb ...
# Unpacking libxshmfence1:amd64 (1.3-1) ...
# Selecting previously unselected package libxxf86vm1:amd64.
# Preparing to unpack .../081-libxxf86vm1_1%3a1.1.4-1+b2_amd64.deb ...
# Unpacking libxxf86vm1:amd64 (1:1.1.4-1+b2) ...
# Selecting previously unselected package libdrm-amdgpu1:amd64.
# Preparing to unpack .../082-libdrm-amdgpu1_2.4.97-1_amd64.deb ...
# 7Progress: [ 32%] [##################........................................] 8Unpacking libdrm-amdgpu1:amd64 (2.4.97-1) ...
# Selecting previously unselected package libpciaccess0:amd64.
# Preparing to unpack .../083-libpciaccess0_0.14-1_amd64.deb ...
# Unpacking libpciaccess0:amd64 (0.14-1) ...
# Selecting previously unselected package libdrm-intel1:amd64.
# Preparing to unpack .../084-libdrm-intel1_2.4.97-1_amd64.deb ...
# Unpacking libdrm-intel1:amd64 (2.4.97-1) ...
# 7Progress: [ 33%] [###################.......................................] 8Selecting previously unselected package libdrm-nouveau2:amd64.
# Preparing to unpack .../085-libdrm-nouveau2_2.4.97-1_amd64.deb ...
# Unpacking libdrm-nouveau2:amd64 (2.4.97-1) ...
# Selecting previously unselected package libdrm-radeon1:amd64.
# Preparing to unpack .../086-libdrm-radeon1_2.4.97-1_amd64.deb ...
# Unpacking libdrm-radeon1:amd64 (2.4.97-1) ...
# Selecting previously unselected package libllvm7:amd64.
# Preparing to unpack .../087-libllvm7_1%3a7.0.1-8+deb10u2_amd64.deb ...
# 7Progress: [ 34%] [###################.......................................] 8Unpacking libllvm7:amd64 (1:7.0.1-8+deb10u2) ...
# Selecting previously unselected package libsensors-config.
# Preparing to unpack .../088-libsensors-config_1%3a3.5.0-3_all.deb ...
# Unpacking libsensors-config (1:3.5.0-3) ...
# Selecting previously unselected package libsensors5:amd64.
# Preparing to unpack .../089-libsensors5_1%3a3.5.0-3_amd64.deb ...
# Unpacking libsensors5:amd64 (1:3.5.0-3) ...
# 7Progress: [ 35%] [####################......................................] 8Selecting previously unselected package libgl1-mesa-dri:amd64.
# Preparing to unpack .../090-libgl1-mesa-dri_18.3.6-2+deb10u1_amd64.deb ...
# Unpacking libgl1-mesa-dri:amd64 (18.3.6-2+deb10u1) ...
# Selecting previously unselected package libglx-mesa0:amd64.
# Preparing to unpack .../091-libglx-mesa0_18.3.6-2+deb10u1_amd64.deb ...
# Unpacking libglx-mesa0:amd64 (18.3.6-2+deb10u1) ...
# Selecting previously unselected package libglx0:amd64.
# Preparing to unpack .../092-libglx0_1.1.0-1_amd64.deb ...
# 7Progress: [ 36%] [####################......................................] 8Unpacking libglx0:amd64 (1.1.0-1) ...
# Selecting previously unselected package libgl1:amd64.
# Preparing to unpack .../093-libgl1_1.1.0-1_amd64.deb ...
# Unpacking libgl1:amd64 (1.1.0-1) ...
# Selecting previously unselected package libiec61883-0:amd64.
# Preparing to unpack .../094-libiec61883-0_1.2.0-3_amd64.deb ...
# Unpacking libiec61883-0:amd64 (1.2.0-3) ...
# 7Progress: [ 37%] [#####################.....................................] 8Selecting previously unselected package libjack-jackd2-0:amd64.
# Preparing to unpack .../095-libjack-jackd2-0_1.9.12~dfsg-2_amd64.deb ...
# Unpacking libjack-jackd2-0:amd64 (1.9.12~dfsg-2) ...
# Selecting previously unselected package libopenal-data.
# Preparing to unpack .../096-libopenal-data_1%3a1.19.1-1_all.deb ...
# Unpacking libopenal-data (1:1.19.1-1) ...
# Selecting previously unselected package libsndio7.0:amd64.
# Preparing to unpack .../097-libsndio7.0_1.5.0-3_amd64.deb ...
# 7Progress: [ 38%] [######################....................................] 8Unpacking libsndio7.0:amd64 (1.5.0-3) ...
# Selecting previously unselected package libopenal1:amd64.
# Preparing to unpack .../098-libopenal1_1%3a1.19.1-1_amd64.deb ...
# Unpacking libopenal1:amd64 (1:1.19.1-1) ...
# Selecting previously unselected package libasyncns0:amd64.
# Preparing to unpack .../099-libasyncns0_0.8-6_amd64.deb ...
# Unpacking libasyncns0:amd64 (0.8-6) ...
# Selecting previously unselected package libcap2:amd64.
# Preparing to unpack .../100-libcap2_1%3a2.25-2_amd64.deb ...
# 7Progress: [ 39%] [######################....................................] 8Unpacking libcap2:amd64 (1:2.25-2) ...
# Selecting previously unselected package libflac8:amd64.
# Preparing to unpack .../101-libflac8_1.3.2-3_amd64.deb ...
# Unpacking libflac8:amd64 (1.3.2-3) ...
# Selecting previously unselected package libsndfile1:amd64.
# Preparing to unpack .../102-libsndfile1_1.0.28-6+deb10u1_amd64.deb ...
# Unpacking libsndfile1:amd64 (1.0.28-6+deb10u1) ...
# 7Progress: [ 40%] [#######################...................................] 8Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../103-libxtst6_2%3a1.2.3-1_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1) ...
# Selecting previously unselected package libpulse0:amd64.
# Preparing to unpack .../104-libpulse0_12.2-4+deb10u1_amd64.deb ...
# Unpacking libpulse0:amd64 (12.2-4+deb10u1) ...
# Selecting previously unselected package libwayland-client0:amd64.
# Preparing to unpack .../105-libwayland-client0_1.16.0-1_amd64.deb ...
# 7Progress: [ 41%] [#######################...................................] 8Unpacking libwayland-client0:amd64 (1.16.0-1) ...
# Selecting previously unselected package libwayland-cursor0:amd64.
# Preparing to unpack .../106-libwayland-cursor0_1.16.0-1_amd64.deb ...
# Unpacking libwayland-cursor0:amd64 (1.16.0-1) ...
# Selecting previously unselected package libwayland-egl1:amd64.
# Preparing to unpack .../107-libwayland-egl1_1.16.0-1_amd64.deb ...
# Unpacking libwayland-egl1:amd64 (1.16.0-1) ...
# 7Progress: [ 42%] [########################..................................] 8Selecting previously unselected package xkb-data.
# Preparing to unpack .../108-xkb-data_2.26-2_all.deb ...
# Unpacking xkb-data (2.26-2) ...
# Selecting previously unselected package libxkbcommon0:amd64.
# Preparing to unpack .../109-libxkbcommon0_0.8.2-1_amd64.deb ...
# Unpacking libxkbcommon0:amd64 (0.8.2-1) ...
# Selecting previously unselected package libxss1:amd64.
# Preparing to unpack .../110-libxss1_1%3a1.2.3-1_amd64.deb ...
# 7Progress: [ 43%] [########################..................................] 8Unpacking libxss1:amd64 (1:1.2.3-1) ...
# Selecting previously unselected package libsdl2-2.0-0:amd64.
# Preparing to unpack .../111-libsdl2-2.0-0_2.0.9+dfsg1-1_amd64.deb ...
# Unpacking libsdl2-2.0-0:amd64 (2.0.9+dfsg1-1) ...
# Selecting previously unselected package libxcb-shape0:amd64.
# Preparing to unpack .../112-libxcb-shape0_1.13.1-2_amd64.deb ...
# Unpacking libxcb-shape0:amd64 (1.13.1-2) ...
# 7Progress: [ 44%] [#########################.................................] 8Selecting previously unselected package libxcb-xfixes0:amd64.
# Preparing to unpack .../113-libxcb-xfixes0_1.13.1-2_amd64.deb ...
# Unpacking libxcb-xfixes0:amd64 (1.13.1-2) ...
# Selecting previously unselected package libxv1:amd64.
# Preparing to unpack .../114-libxv1_2%3a1.0.11-1_amd64.deb ...
# Unpacking libxv1:amd64 (2:1.0.11-1) ...
# Selecting previously unselected package libavdevice58:amd64.
# Preparing to unpack .../115-libavdevice58_7%3a4.1.8-0+deb10u1_amd64.deb ...
# 7Progress: [ 45%] [##########################................................] 8Unpacking libavdevice58:amd64 (7:4.1.8-0+deb10u1) ...
# Selecting previously unselected package libavresample4:amd64.
# Preparing to unpack .../116-libavresample4_7%3a4.1.8-0+deb10u1_amd64.deb ...
# Unpacking libavresample4:amd64 (7:4.1.8-0+deb10u1) ...
# Selecting previously unselected package ffmpeg.
# Preparing to unpack .../117-ffmpeg_7%3a4.1.8-0+deb10u1_amd64.deb ...
# Unpacking ffmpeg (7:4.1.8-0+deb10u1) ...
# 7Progress: [ 46%] [##########################................................] 8Selecting previously unselected package i965-va-driver:amd64.
# Preparing to unpack .../118-i965-va-driver_2.3.0+dfsg1-1_amd64.deb ...
# Unpacking i965-va-driver:amd64 (2.3.0+dfsg1-1) ...
# Selecting previously unselected package libigdgmm5:amd64.
# Preparing to unpack .../119-libigdgmm5_18.4.1+ds1-1_amd64.deb ...
# Unpacking libigdgmm5:amd64 (18.4.1+ds1-1) ...
# Selecting previously unselected package intel-media-va-driver:amd64.
# Preparing to unpack .../120-intel-media-va-driver_18.4.1+dfsg1-1_amd64.deb ...
# Unpacking intel-media-va-driver:amd64 (18.4.1+dfsg1-1) ...
# 7Progress: [ 47%] [###########################...............................] 8Selecting previously unselected package libaacs0:amd64.
# Preparing to unpack .../121-libaacs0_0.9.0-2_amd64.deb ...
# Unpacking libaacs0:amd64 (0.9.0-2) ...
# Selecting previously unselected package libbdplus0:amd64.
# Preparing to unpack .../122-libbdplus0_0.1.2-3_amd64.deb ...
# Unpacking libbdplus0:amd64 (0.1.2-3) ...
# Selecting previously unselected package libvdpau-va-gl1:amd64.
# Preparing to unpack .../123-libvdpau-va-gl1_0.4.2-1+b1_amd64.deb ...
# 7Progress: [ 48%] [###########################...............................] 8Unpacking libvdpau-va-gl1:amd64 (0.4.2-1+b1) ...
# Selecting previously unselected package mesa-va-drivers:amd64.
# Preparing to unpack .../124-mesa-va-drivers_18.3.6-2+deb10u1_amd64.deb ...
# Unpacking mesa-va-drivers:amd64 (18.3.6-2+deb10u1) ...
# Selecting previously unselected package mesa-vdpau-drivers:amd64.
# Preparing to unpack .../125-mesa-vdpau-drivers_18.3.6-2+deb10u1_amd64.deb ...
# Unpacking mesa-vdpau-drivers:amd64 (18.3.6-2+deb10u1) ...
# 7Progress: [ 49%] [############################..............................] 8Selecting previously unselected package va-driver-all:amd64.
# Preparing to unpack .../126-va-driver-all_2.4.0-1_amd64.deb ...
# Unpacking va-driver-all:amd64 (2.4.0-1) ...
# Selecting previously unselected package vdpau-driver-all:amd64.
# Preparing to unpack .../127-vdpau-driver-all_1.1.1-10_amd64.deb ...
# Unpacking vdpau-driver-all:amd64 (1.1.1-10) ...
# Setting up libgme0:amd64 (0.6.2-1) ...
# 7Progress: [ 50%] [#############################.............................] 8Setting up libssh-gcrypt-4:amd64 (0.8.7-1+deb10u1) ...
# Setting up libxcb-dri3-0:amd64 (1.13.1-2) ...
# 7Progress: [ 51%] [#############################.............................] 8Setting up libigdgmm5:amd64 (18.4.1+ds1-1) ...
# Setting up libx11-xcb1:amd64 (2:1.6.7-1+deb10u2) ...
# Setting up libpciaccess0:amd64 (0.14-1) ...
# 7Progress: [ 52%] [##############################............................] 8Setting up libraw1394-11:amd64 (2.1.2-1+b1) ...
# Setting up libsodium23:amd64 (1.0.17-1) ...
# 7Progress: [ 53%] [##############################............................] 8Setting up libmpg123-0:amd64 (1.25.10-2) ...
# Setting up libxcb-xfixes0:amd64 (1.13.1-2) ...
# Setting up libogg0:amd64 (1.3.2-1+b1) ...
# 7Progress: [ 54%] [###############################...........................] 8Setting up libspeex1:amd64 (1.2~rc1.2-1+b2) ...
# Setting up libshine3:amd64 (3.1.1-2) ...
# Setting up libtwolame0:amd64 (0.3.13-4) ...
# 7Progress: [ 55%] [###############################...........................] 8Setting up libgsm1:amd64 (1.0.18-2) ...
# Setting up libx264-155:amd64 (2:0.155.2917+git0a84d98-2) ...
# 7Progress: [ 56%] [################################..........................] 8Setting up libsoxr0:amd64 (0.1.2-3) ...
# Setting up libglvnd0:amd64 (1.1.0-1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1) ...
# 7Progress: [ 57%] [#################################.........................] 8Setting up libxcb-glx0:amd64 (1.13.1-2) ...
# Setting up libaom0:amd64 (1.0.0-3) ...
# 7Progress: [ 58%] [#################################.........................] 8Setting up libcodec2-0.8.1:amd64 (0.8.1-2) ...
# Setting up libnorm1:amd64 (1.5.8+dfsg2-1) ...
# Setting up libxcb-shape0:amd64 (1.13.1-2) ...
# 7Progress: [ 59%] [##################################........................] 8Setting up libsensors-config (1:3.5.0-3) ...
# Setting up libcdio18:amd64 (2.0.0-2) ...
# 7Progress: [ 60%] [##################################........................] 8Setting up xkb-data (2.26-2) ...
# Setting up libmysofa0:amd64 (0.6~dfsg0-3+deb10u1) ...
# Setting up libcrystalhd3:amd64 (1:0.0~git20110715.fdd2f19-13) ...
# 7Progress: [ 61%] [###################################.......................] 8Setting up libxvidcore4:amd64 (2:1.3.5-1) ...
# Setting up libcap2:amd64 (1:2.25-2) ...
# Setting up libxxf86vm1:amd64 (1:1.1.4-1+b2) ...
# 7Progress: [ 62%] [####################################......................] 8Setting up libsnappy1v5:amd64 (1.1.7-1) ...
# Setting up libflac8:amd64 (1.3.2-3) ...
# 7Progress: [ 63%] [####################################......................] 8Setting up libxcb-present0:amd64 (1.13.1-2) ...
# Setting up libasound2-data (1.1.8-1) ...
# Setting up libass9:amd64 (1:0.14.0-2) ...
# 7Progress: [ 64%] [#####################################.....................] 8Setting up libslang2:amd64 (2.3.2-2) ...
# Setting up libva2:amd64 (2.4.0-1) ...
# 7Progress: [ 65%] [#####################################.....................] 8Setting up libxcb-sync1:amd64 (1.13.1-2) ...
# Setting up libopus0:amd64 (1.3-1) ...
# Setting up intel-media-va-driver:amd64 (18.4.1+dfsg1-1) ...
# 7Progress: [ 66%] [######################################....................] 8Setting up libxv1:amd64 (2:1.0.11-1) ...
# Setting up libvorbis0a:amd64 (1.3.6-2) ...
# 7Progress: [ 67%] [######################################....................] 8Setting up libsensors5:amd64 (1:3.5.0-3) ...
# Setting up libaacs0:amd64 (0.9.0-2) ...
# Setting up libfftw3-double3:amd64 (3.3.8-2) ...
# 7Progress: [ 68%] [#######################################...................] 8Setting up libglapi-mesa:amd64 (18.3.6-2+deb10u1) ...
# Setting up libxcb-dri2-0:amd64 (1.13.1-2) ...
# 7Progress: [ 69%] [########################################..................] 8Setting up libbdplus0:amd64 (0.1.2-3) ...
# Setting up libnuma1:amd64 (2.0.12-1) ...
# Setting up libvidstab1.1:amd64 (1.1.0-2) ...
# 7Progress: [ 70%] [########################################..................] 8Setting up libasyncns0:amd64 (0.8-6) ...
# Setting up libxshmfence1:amd64 (1.3-1) ...
# Setting up libvdpau1:amd64 (1.1.1-10) ...
# 7Progress: [ 71%] [#########################################.................] 8Setting up libwavpack1:amd64 (5.1.0-6) ...
# Setting up libbs2b0:amd64 (3.1.0+dfsg-2.2) ...
# 7Progress: [ 72%] [#########################################.................] 8Setting up libtheora0:amd64 (1.1.1+dfsg.1-15) ...
# Setting up libasound2:amd64 (1.1.8-1) ...
# Setting up libopenjp2-7:amd64 (2.3.0-2+deb10u2) ...
# 7Progress: [ 73%] [##########################################................] 8Setting up libllvm7:amd64 (1:7.0.1-8+deb10u2) ...
# Setting up libopenal-data (1:1.19.1-1) ...
# 7Progress: [ 74%] [##########################################................] 8Setting up libwayland-egl1:amd64 (1.16.0-1) ...
# Setting up libxss1:amd64 (1:1.2.3-1) ...
# Setting up libusb-1.0-0:amd64 (2:1.0.22-2) ...
# 7Progress: [ 75%] [###########################################...............] 8Setting up libbluray2:amd64 (1:1.1.0-1) ...
# Setting up libsamplerate0:amd64 (0.1.9-2) ...
# 7Progress: [ 76%] [############################################..............] 8Setting up libwebpmux3:amd64 (0.6.1-2+deb10u1) ...
# Setting up libdrm-common (2.4.97-1) ...
# Setting up libzvbi-common (0.2.35-16) ...
# 7Progress: [ 77%] [############################################..............] 8Setting up libmp3lame0:amd64 (3.100-2+b1) ...
# Setting up libvpx5:amd64 (1.7.0-3+deb10u1) ...
# Setting up libvorbisenc2:amd64 (1.3.6-2) ...
# 7Progress: [ 78%] [#############################################.............] 8Setting up libpgm-5.2-0:amd64 (5.2.122~dfsg-3) ...
# Setting up libiec61883-0:amd64 (1.2.0-3) ...
# 7Progress: [ 79%] [#############################################.............] 8Setting up libserd-0-0:amd64 (0.28.0~dfsg0-1) ...
# Setting up libxkbcommon0:amd64 (0.8.2-1) ...
# Setting up libwayland-client0:amd64 (1.16.0-1) ...
# 7Progress: [ 80%] [##############################################............] 8Setting up libavc1394-0:amd64 (0.5.4-5) ...
# Setting up libzvbi0:amd64 (0.2.35-16) ...
# 7Progress: [ 81%] [###############################################...........] 8Setting up libzmq5:amd64 (4.3.1-4+deb10u2) ...
# Setting up libcaca0:amd64 (0.99.beta19-2.1) ...
# Setting up libcdio-cdda2:amd64 (10.2+0.94+2-4) ...
# 7Progress: [ 82%] [###############################################...........] 8Setting up libx265-165:amd64 (2.9-4) ...
# Setting up libcdio-paranoia2:amd64 (10.2+0.94+2-4) ...
# 7Progress: [ 83%] [################################################..........] 8Setting up libdc1394-22:amd64 (2.2.5-1) ...
# Setting up libvorbisfile3:amd64 (1.3.6-2) ...
# Setting up librubberband2:amd64 (1.8.1-7) ...
# 7Progress: [ 84%] [################################################..........] 8Setting up libsndio7.0:amd64 (1.5.0-3) ...
# Setting up libjack-jackd2-0:amd64 (1.9.12~dfsg-2) ...
# Setting up libdrm2:amd64 (2.4.97-1) ...
# 7Progress: [ 85%] [#################################################.........] 8Setting up libflite1:amd64 (2.1-release-3) ...
# Setting up libva-drm2:amd64 (2.4.0-1) ...
# 7Progress: [ 86%] [#################################################.........] 8Setting up libsord-0-0:amd64 (0.16.0~dfsg0-1+b1) ...
# Setting up libwayland-cursor0:amd64 (1.16.0-1) ...
# Setting up libsratom-0-0:amd64 (0.6.0~dfsg0-1) ...
# 7Progress: [ 87%] [##################################################........] 8Setting up libsndfile1:amd64 (1.0.28-6+deb10u1) ...
# Setting up libva-x11-2:amd64 (2.4.0-1) ...
# 7Progress: [ 88%] [###################################################.......] 8Setting up liblilv-0-0:amd64 (0.24.2~dfsg0-2) ...
# Setting up libopenmpt0:amd64 (0.4.3-1+deb10u1) ...
# Setting up libdrm-amdgpu1:amd64 (2.4.97-1) ...
# 7Progress: [ 89%] [###################################################.......] 8Setting up libdrm-nouveau2:amd64 (2.4.97-1) ...
# Setting up libpulse0:amd64 (12.2-4+deb10u1) ...
# 7Progress: [ 90%] [####################################################......] 8Setting up libdrm-radeon1:amd64 (2.4.97-1) ...
# Setting up libdrm-intel1:amd64 (2.4.97-1) ...
# Setting up libgl1-mesa-dri:amd64 (18.3.6-2+deb10u1) ...
# 7Progress: [ 91%] [####################################################......] 8Setting up libopenal1:amd64 (1:1.19.1-1) ...
# Setting up libavutil56:amd64 (7:4.1.8-0+deb10u1) ...
# 7Progress: [ 92%] [#####################################################.....] 8Setting up libpostproc55:amd64 (7:4.1.8-0+deb10u1) ...
# Setting up libswscale5:amd64 (7:4.1.8-0+deb10u1) ...
# Setting up mesa-va-drivers:amd64 (18.3.6-2+deb10u1) ...
# 7Progress: [ 93%] [######################################################....] 8Setting up libsdl2-2.0-0:amd64 (2.0.9+dfsg1-1) ...
# Setting up i965-va-driver:amd64 (2.3.0+dfsg1-1) ...
# Setting up mesa-vdpau-drivers:amd64 (18.3.6-2+deb10u1) ...
# 7Progress: [ 94%] [######################################################....] 8Setting up libglx-mesa0:amd64 (18.3.6-2+deb10u1) ...
# Setting up libglx0:amd64 (1.1.0-1) ...
# 7Progress: [ 95%] [#######################################################...] 8Setting up libswresample3:amd64 (7:4.1.8-0+deb10u1) ...
# Setting up libavresample4:amd64 (7:4.1.8-0+deb10u1) ...
# Setting up libgl1:amd64 (1.1.0-1) ...
# 7Progress: [ 96%] [#######################################################...] 8Setting up va-driver-all:amd64 (2.4.0-1) ...
# Setting up libavcodec58:amd64 (7:4.1.8-0+deb10u1) ...
# 7Progress: [ 97%] [########################################################..] 8Setting up libvdpau-va-gl1:amd64 (0.4.2-1+b1) ...
# Setting up libchromaprint1:amd64 (1.4.3-3) ...
# Setting up libavformat58:amd64 (7:4.1.8-0+deb10u1) ...
# 7Progress: [ 98%] [########################################################..] 8Setting up vdpau-driver-all:amd64 (1.1.1-10) ...
# Setting up libavfilter7:amd64 (7:4.1.8-0+deb10u1) ...
# 7Progress: [ 99%] [#########################################################.] 8Setting up libavdevice58:amd64 (7:4.1.8-0+deb10u1) ...
# Setting up ffmpeg (7:4.1.8-0+deb10u1) ...
# Processing triggers for libc-bin (2.28-10) ...
#
# 78Collecting scikit-image
#   Downloading scikit_image-0.18.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (30.2 MB)
#      |████████████████████████████████| 30.2 MB 30.7 MB/s
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from scikit-image) (8.3.2)
# Collecting networkx>=2.0
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 74.9 MB/s
# Requirement already satisfied: numpy>=1.16.5 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from scikit-image) (1.19.5)
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.1.1-cp38-cp38-manylinux1_x86_64.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 18.9 MB/s
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2021.11.2-py3-none-any.whl (178 kB)
#      |████████████████████████████████| 178 kB 77.2 MB/s
# Requirement already satisfied: scipy>=1.0.1 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from scikit-image) (1.7.1)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from scikit-image) (3.4.3)
# Collecting imageio>=2.3.0
#   Downloading imageio-2.10.1-py3-none-any.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 67.2 MB/s
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image) (1.3.2)
# Requirement already satisfied: six in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from cycler>=0.10->matplotlib!=3.0.0,>=2.0.0->scikit-image) (1.16.0)
# Installing collected packages: tifffile, PyWavelets, networkx, imageio, scikit-image
# Successfully installed PyWavelets-1.1.1 imageio-2.10.1 networkx-2.6.3 scikit-image-0.18.3 tifffile-2021.11.2
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# Collecting opencv-python
#   Downloading opencv_python-4.5.4.58-cp38-cp38-manylinux2014_x86_64.whl (60.3 MB)
#      |████████████████████████████████| 60.3 MB 32.4 MB/s
# Requirement already satisfied: numpy>=1.17.3 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from opencv-python) (1.19.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.4.58
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# Collecting opencv-contrib-python
#   Downloading opencv_contrib_python-4.5.4.58-cp38-cp38-manylinux2014_x86_64.whl (66.5 MB)
#      |████████████████████████████████| 66.5 MB 51 kB/s
# Requirement already satisfied: numpy>=1.17.3 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from opencv-contrib-python) (1.19.5)
# Installing collected packages: opencv-contrib-python
# Successfully installed opencv-contrib-python-4.5.4.58
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import torch
import sklearn
from sklearn.neighbors import NearestNeighbors
from scipy.spatial.distance import cdist
import os
#from pytorchsuperpointmaster.models.SuperPointNet_pretrained import SuperPointNet
from PIL import Image

# %%
im_castle_1 = 'hpatches-sequences-release/i_castle/1.ppm'
im_castle_6 = 'hpatches-sequences-release/i_castle/6.ppm'
im_lion_1 = 'hpatches-sequences-release/i_lionnight/1.ppm'
im_lion_3 = 'hpatches-sequences-release/i_lionnight/3.ppm'

fold = 'hpatches-sequences-release'
im_set_i = list(filter(lambda x: x[0] == 'i', os.listdir(fold)))[:10]
im_set_v = list(filter(lambda x: x[0] == 'v', os.listdir(fold)))[:10]

def computeSeries(im_set, computeFunc, extractor):
    fold = 'hpatches-sequences-release'

    res = 0
    c = 1
    for name in im_set:
        print(f'\r{c}/{len(im_set)}',end='')
        path = f"{fold}/{name}/"
        im1 = path + '1.ppm'
        images = [path+str(i)+'.ppm' for i in range(2,7)]
        H = [np.loadtxt(path + 'H_1_'+str(i)) for i in range(2,7)]

        for im,h in zip(images,H):
            res += computeFunc(*extractor(im1, im, h))
        c+=1

    return res/(len(im_set)*5)

# %%
def computeSeriesLE(im_set, computeFunc, extractor, eps):
    fold = 'hpatches-sequences-release'

    res = 0
    c = 1
    for name in im_set:
        print(f'\r{c}/{len(im_set)}',end='')
        path = f"{fold}/{name}/"
        im1 = path + '1.ppm'
        images = [path+str(i)+'.ppm' for i in range(2,7)]
        H = [np.loadtxt(path + 'H_1_'+str(i)) for i in range(2,7)]

        for im,h in zip(images,H):
            t = computeFunc(*extractor(im1, im, h))
            res += t if t > 0.01 else eps
        c+=1

    return res/(len(im_set)*5)

# %%
def computeSeriesH(im_set, computeFunc, extractor):
    fold = 'hpatches-sequences-release'

    res = 0
    c = 1
    for name in im_set:
        print(f'\r{c}/{len(im_set)}',end='')
        path = f"{fold}/{name}/"
        im1 = path + '1.ppm'
        images = [path+str(i)+'.ppm' for i in range(2,7)]
        H = [np.loadtxt(path + 'H_1_'+str(i)) for i in range(2,7)]

        for im,h in zip(images,H):
            res += (computeFunc(*extractor(im1, im, h)) <= 5)
        c+=1

    return res/(len(im_set)*5)

# %%
eps = 1
#res = computeSeries(im_set_i+im_set_v, computeDescriptors, lambda im1, im2, _: ['SURF', im1, im2, 1])
#res = computeSeriesLE(im_set_i+im_set_v, computeLocalizationError, lambda im1, im2, h: ['SIFT', im1, im2, eps, h], eps)
res = computeSeriesH(im_set_i+im_set_v, computeHomographyError, lambda im1, im2, h: ['SURF', im1, im2, h])
print('\n',res)
# Out:
# 20/20
#  0.66

# %%
def computeTrueMatches(descriptor,img1,img2,eps,homography=None):
    #-- Step 0: Load images
    im1 = plt.imread(img1)
    #im1 = cv2.cvtColor(im1,cv2.COLOR_BGR2GRAY)
    im2 = plt.imread(img2)
    #im2 = cv2.cvtColor(im2,cv2.COLOR_BGR2GRAY)
    im = np.concatenate((im1,im2),axis=1).astype(np.uint8)
    #-- Step 1: Detect the keypoints using SURF Detector, compute the descriptors
    if(descriptor == 'SIFT'):
        detector = cv2.xfeatures2d.SIFT_create()
    elif(descriptor == 'SURF'):
        detector = cv2.xfeatures2d.SURF_create(400)
    elif(descriptor == 'ORB'):
        detector = cv2.ORB_create()
    kp1, _ = detector.detectAndCompute(im1, None)
    kp2, _ = detector.detectAndCompute(im2, None)
    kp1 = np.array(list(map(lambda x: [x.pt[0], x.pt[1]], kp1)))
    kp1_org = kp1.copy()
    kp2 = np.array(list(map(lambda x: [x.pt[0], x.pt[1]], kp2)))
    if(homography is not None):
        X = kp1[:,0]
        Y = kp1[:,1]
        ones = np.ones_like(X)
        points = np.stack((X,Y,ones),axis=0)
        transformed = homography@points
        kp1 = np.array([transformed[:2,i] for i in range(points.shape[1])])
    
    neigh = NearestNeighbors(n_neighbors=1,radius=eps)
    neigh = neigh.fit(kp1)
    kp1_idx = np.zeros(len(kp1))
    matches = []
    dist, idx = neigh.radius_neighbors(kp2,return_distance=True,sort_results=True)
    for n,i_arr,dist_arr in zip(range(len(idx)),idx,dist):
        for i,d in zip(i_arr,dist_arr):
            if kp1_idx[i] == 0:
                kp1_idx[i] = 1
                matches.append([n,i])
                break
            
    out = img2
    for match in matches:
        p2 = (int(kp2[match[0]][0] + im1.shape[1]),int(kp2[match[0]][1]))
        p1 = (int(kp1_org[match[1]][0]),int(kp1_org[match[1]][1]))
        c = tuple(np.random.choice(range(256), size=3).tolist())
        out = cv2.line(im,p1,p2,color=c,thickness=2)
        
    
    plt.figure(figsize=(18,36))
    plt.imshow(out)

im_name = 'boat'
im1 = f'hpatches-sequences-release/v_{im_name}/1.ppm'
im2 = f'hpatches-sequences-release/v_{im_name}/6.ppm'
h_1_6 = np.loadtxt(f'hpatches-sequences-release/v_{im_name}/H_1_6')
computeTrueMatches('SURF',im1,im2,1,homography=h_1_6)

# %%
plt.figure(figsize=(12,8))
plt.plot(np.linspace(0,1,10),np.linspace(0,1,10),linestyle='dashed')
plt.scatter((1-res[1])[::-1],res[0],label='SIFT')
plt.xlim(-0.01,1.01)
plt.ylim(-0.01,1.01)
plt.xlabel('Recall',fontsize=18)
plt.ylabel('Precision',fontsize=18)
plt.title('i_castle_1 / i_castle_6',fontsize=22)
plt.legend()
plt.show()

# %%
def computeMatches(descriptor,img1,img2):
    #-- Step 0: Load images
    im1 = cv2.imread(img1)
    im1 = cv2.cvtColor(im1,cv2.COLOR_BGR2GRAY)
    im2 = cv2.imread(img2)
    im2 = cv2.cvtColor(im2,cv2.COLOR_BGR2GRAY)
    #-- Step 1: Detect the keypoints using SURF Detector, compute the descriptors
    if(descriptor == 'SIFT'):
        detector = cv2.xfeatures2d.SIFT_create()
    elif(descriptor == 'SURF'):
        detector = cv2.xfeatures2d.SURF_create(400)
    elif(descriptor == 'ORB'):
        detector = cv2.ORB_create()
    keypoints1, descriptors1 = detector.detectAndCompute(im1, None)
    keypoints2, descriptors2 = detector.detectAndCompute(im2, None)
    descriptors1 = np.float32(descriptors1)
    descriptors2 = np.float32(descriptors2)
    #-- Step 2: Matching descriptor vectors with a FLANN based matcher
    matcher = cv2.DescriptorMatcher_create(cv2.DescriptorMatcher_FLANNBASED)
    knn_matches = matcher.knnMatch(descriptors1, descriptors2, 2)
    #-- Filter matches using the Lowe's ratio test
    ratio_thresh = 1
    good_matches = []
    for m,n in knn_matches:
        if m.distance < ratio_thresh * n.distance:
            good_matches.append(m)
    #-- Draw matches
    img_matches = np.empty((max(im1.shape[0], im2.shape[0]), im1.shape[1]+im2.shape[1], 3), dtype=np.uint8)
    #cv2.drawMatches(im1, keypoints1, im2, keypoints2, good_matches, img_matches, 2, matchColor=-1, flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)
    cv2.drawMatches(im1, keypoints1, im2, keypoints2, good_matches, img_matches, -1, flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)
    #-- Show detected matches
    plt.figure(figsize=(18,36))
    plt.imshow(img_matches)

# %%
computeMatches('SURF',im_castle_1,im_castle_6)

# %%
def computeKeypoints(descriptor,img1,img2,max_eps):
    #-- Step 0: Load images
    im1 = cv2.imread(img1)
    im1 = cv2.cvtColor(im1,cv2.COLOR_BGR2GRAY)
    im2 = cv2.imread(img2)
    im2 = cv2.cvtColor(im2,cv2.COLOR_BGR2GRAY)
    #-- Step 1: Detect the keypoints using SURF Detector, compute the descriptors
    if(descriptor == 'SIFT'):
        detector = cv2.xfeatures2d.SIFT_create()
    elif(descriptor == 'SURF'):
        detector = cv2.xfeatures2d.SURF_create(400)
    elif(descriptor == 'ORB'):
        detector = cv2.ORB_create()
    kp1, _ = detector.detectAndCompute(im1, None)
    kp2, _ = detector.detectAndCompute(im2, None)
    kp1 = np.array(list(map(lambda x: [x.pt[0], x.pt[1]], kp1)))
    kp2 = np.array(list(map(lambda x: [x.pt[0], x.pt[1]], kp2)))
    points = 400
    
    epsilons = []
    for eps in np.linspace(0,max_eps,points):
        print(f'\r{(eps/max_eps)*50:.2f}%',end='')
        neigh = NearestNeighbors(n_neighbors=1,radius=eps)
        neigh = neigh.fit(kp1)
        precision = np.zeros(len(kp1))
        _, idx = neigh.radius_neighbors(kp2,return_distance=True,sort_results=True)
        for i_arr in idx:
            for i in i_arr:
                if precision[i] == 0:
                    precision[i] = 1
                    break

        epsilons.append(precision)
    
    epsilons = np.array(epsilons)
    precisions = [np.sum(epsilons[i])/len(kp2) for i in range(epsilons.shape[0])]


    epsilons = []
    for eps in np.linspace(0,max_eps,points):
        print(f'\r{(eps/max_eps)*50+50:.2f}%',end='')
        neigh = NearestNeighbors(n_neighbors=1,radius=eps)
        neigh = neigh.fit(kp2)
        recall = np.zeros(len(kp2))
        _, idx = neigh.radius_neighbors(kp1,return_distance=True,sort_results=True)
        for i_arr in idx:
            for i in i_arr:
                if recall[i] == 0:
                    recall[i] = 1
                    break
        epsilons.append(recall)
    epsilons = np.array(epsilons)
    recalls = [epsilons[i].mean() for i in range(epsilons.shape[0])]
    
    #return precisions, recalls
    return sklearn.metrics.auc((1-np.array(recalls))[::-1], precisions)

# %%
def computeLocalizationError(descriptor,img1,img2,eps,homography=None):
    #-- Step 0: Load images
    im1 = cv2.imread(img1)
    im1 = cv2.cvtColor(im1,cv2.COLOR_BGR2GRAY)
    im2 = cv2.imread(img2)
    im2 = cv2.cvtColor(im2,cv2.COLOR_BGR2GRAY)
    #-- Step 1: Detect the keypoints using SURF Detector, compute the descriptors
    if(descriptor == 'SIFT'):
        detector = cv2.xfeatures2d.SIFT_create()
    elif(descriptor == 'SURF'):
        detector = cv2.xfeatures2d.SURF_create()
    elif(descriptor == 'ORB'):
        detector = cv2.ORB_create()
    kp1, _ = detector.detectAndCompute(im1, None)
    kp2, _ = detector.detectAndCompute(im2, None)
    kp1 = np.array(list(map(lambda x: [x.pt[0], x.pt[1]], kp1)))
    kp2 = np.array(list(map(lambda x: [x.pt[0], x.pt[1]], kp2)))
    if(homography is not None):
        X = kp1[:,0]
        Y = kp1[:,1]
        ones = np.ones_like(X)
        points = np.stack((X,Y,ones),axis=0)
        transformed = homography@points
        kp1 = np.array([transformed[:2,i] for i in range(points.shape[1])])
    
    LE = 0
    neigh = NearestNeighbors(n_neighbors=1,radius=eps)
    neigh = neigh.fit(kp1)
    precision = np.zeros(len(kp1))
    dist, idx = neigh.radius_neighbors(kp2,return_distance=True,sort_results=True)
    for i_arr,dist_arr in zip(idx,dist):
        for i,d in zip(i_arr,dist_arr):
            if precision[i] == 0:
                precision[i] = 1
                LE += d
                break
    
    return LE/(precision.sum() + 1e-10)

# %%
def computeDescriptors(descriptor,img1,img2,max_eps):
    #-- Step 0: Load images
    im1 = cv2.imread(img1)
    im1 = cv2.cvtColor(im1,cv2.COLOR_BGR2GRAY)
    im2 = cv2.imread(img2)
    im2 = cv2.cvtColor(im2,cv2.COLOR_BGR2GRAY)
    #-- Step 1: Detect the keypoints using SURF Detector, compute the descriptors
    if(descriptor == 'SIFT'):
        detector = cv2.xfeatures2d.SIFT_create()
    elif(descriptor == 'SURF'):
        detector = cv2.xfeatures2d.SURF_create()
    elif(descriptor == 'ORB'):
        detector = cv2.ORB_create(nfeatures=1000000)
    _,des1 = detector.detectAndCompute(im1, None)
    _,des2 = detector.detectAndCompute(im2, None)
    des1 = np.array(des1)
    des2 = np.array(des2)
    
    if des1.shape[0] > 1000:
        des1 = des1[:1000,...]
    if des2.shape[0] > 1000:
        des2 = des2[:1000,...]
    
    points = 100
    
    epsilons = []
    for eps in np.linspace(0,max_eps,points):
        #print(f'\r{(eps/max_eps)*50:.2f}%',end='')
        neigh = NearestNeighbors(n_neighbors=1,radius=eps)
        neigh = neigh.fit(des1)
        precision = np.zeros(len(des1))
        _, idx = neigh.radius_neighbors(des2,return_distance=True,sort_results=True)
        for i_arr in idx:
            for i in i_arr:
                if precision[i] == 0:
                    precision[i] = 1

                    break

        epsilons.append(precision)
    
    epsilons = np.array(epsilons)
    precisions = [np.sum(epsilons[i])/len(des2) for i in range(epsilons.shape[0])]


    epsilons = []
    for eps in np.linspace(0,max_eps,points):
        #print(f'\r{(eps/max_eps)*50+50:.2f}%',end='')
        neigh = NearestNeighbors(n_neighbors=1,radius=eps)
        neigh = neigh.fit(des2)
        recall = np.zeros(len(des2))
        _, idx = neigh.radius_neighbors(des1,return_distance=True,sort_results=True)
        for i_arr in idx:
            for i in i_arr:
                if recall[i] == 0:
                    recall[i] = 1
                    break
        epsilons.append(recall)
    epsilons = np.array(epsilons)
    recalls = [np.sum(epsilons[i])/len(des1) for i in range(epsilons.shape[0])]

    precisions /= np.max(precisions)
    recalls /= np.max(recalls)
    #return sklearn.metrics.auc((1-np.array(recalls)), precisions)
    
    return precisions, recalls

# %%
def computeHomographyError(descriptor,img1,img2,h_hat):
    #-- Step 0: Load images
    im1 = cv2.imread(img1)
    im1 = cv2.cvtColor(im1,cv2.COLOR_BGR2GRAY)
    im2 = cv2.imread(img2)
    im2 = cv2.cvtColor(im2,cv2.COLOR_BGR2GRAY)
    #-- Step 1: Detect the keypoints using SURF Detector, compute the descriptors
    if(descriptor == 'SIFT'):
        detector = cv2.xfeatures2d.SIFT_create()
    elif(descriptor == 'SURF'):
        detector = cv2.xfeatures2d.SURF_create()
    elif(descriptor == 'ORB'):
        detector = cv2.ORB_create()

    keypoints1, descriptors1 = detector.detectAndCompute(im1, None)
    keypoints2, descriptors2 = detector.detectAndCompute(im2, None)
    descriptors1 = np.float32(descriptors1)
    descriptors2 = np.float32(descriptors2)
    #-- Step 2: Matching descriptor vectors with a FLANN based matcher
    matcher = cv2.DescriptorMatcher_create(cv2.DescriptorMatcher_FLANNBASED)
    knn_matches = matcher.knnMatch(descriptors1, descriptors2, 2)
    ratio_thresh = 0.7
    good_matches = [] # threshold to len 1000 - superpoint paper
    for m,n in knn_matches:
        if m.distance < ratio_thresh * n.distance:
            good_matches.append(m)
    src = np.array([keypoints1[good_matches[i].queryIdx].pt for i in range(len(good_matches))])
    dst = np.array([keypoints2[good_matches[i].trainIdx].pt for i in range(len(good_matches))])

    # knn_matches = np.array(matcher.knnMatch(descriptors1, descriptors2, 1))
    # src = np.array([keypoints1[knn_matches[i,0].queryIdx].pt for i in range(len(knn_matches))])
    # dst = np.array([keypoints2[knn_matches[i,0].trainIdx].pt for i in range(len(knn_matches))])

    h_true,_ = cv2.findHomography(src,dst,cv2.RANSAC)

    corners = np.array([[0,0],[0,im1.shape[1]],[im1.shape[0],0],[im1.shape[0],im1.shape[1]]])

    X = corners[:,0]
    Y = corners[:,1]
    ones = np.ones_like(X)
    points = np.stack((X,Y,ones),axis=0)
    t_hat = h_hat@points
    t_true = h_true@points
    c_hat = np.array([t_hat[:2,i] for i in range(points.shape[1])])
    c_true = np.array([t_true[:2,i] for i in range(points.shape[1])])
    
    return np.abs(c_true - c_hat).sum()/4

# %%
h = np.identity(3)
print(computeHomographyError('SIFT',im_lion_1,im_lion_3,h))
# Out:
# 2.4636623428781483

# %%
computeDescriptors('SURF',im_lion_1,im_lion_3,900)
# Out:
# (2522, 64)
# 1.0

# %% [markdown]
# # Feature points

# %%
# print('SIFT:')
# siftP, siftR = computeDescriptors('SIFT',im_castle_1,im_castle_6,800)
# print('\nORB:')
# orbP, orbR = computeDescriptors('ORB',im_castle_1,im_castle_6,800)
# print('\nSURF:')
# surfP, surfR = computeDescriptors('SURF',im_castle_1,im_castle_6,1)
plt.figure(figsize=(12,8))
plt.plot(np.linspace(0,1,10)[::-1],np.linspace(0,1,10),linestyle='dashed')
plt.plot((1-np.array(siftR)),siftP,label='SIFT')
plt.plot((1-np.array(orbR)),orbP,label='ORB')
plt.plot((1-np.array(surfR)),surfP,label='SURF')
plt.xlim(-0.01,1.01)
plt.ylim(-0.01,1.01)
plt.xlabel('1 - Recall',fontsize=18)
plt.ylabel('Precision',fontsize=18)
plt.title('i_castle_1 / i_castle_6',fontsize=22)
plt.legend()
plt.show()

# %%
print(sklearn.metrics.auc((1-np.array(orbR)), orbP))
print(sklearn.metrics.auc((1-np.array(siftR)), siftP))
print(sklearn.metrics.auc(np.linspace(0,1,10), np.linspace(0,1,10)))
# Out:
# 0.602810650887574
# 0.6348044369135376
# 0.5

# %%
print((1-np.array(siftR))[::-1][0],(1-np.array(siftR))[::-1][-1])
print((1-np.array(orbR))[::-1][0],(1-np.array(orbR))[::-1][-1])
# Out:
# 0.04491017964071853 1.0
# 0.28600000000000003 0.928

# %%
def area_under_curve(recalls, precisions):
    recalls, precisions = np.array(recalls), np.array(precisions)
    dr = recalls[1:]-recalls[:-1]
    print(dr.sum())
    dp = dr*precisions[1:]
    return np.sum(dp)


print(area_under_curve((1-np.array(orbR))[::-1], orbP))
print('')
print(area_under_curve((1-np.array(siftR))[::-1], siftP))
# Out:
# 0.928
# 0.92704
#
# 0.998003992015968
# 0.9926832960824856

# %%
h = np.identity(3)
print(computeLocalizationError('SIFT',im_lion_1,im_lion_3,4,homography=h))
print(computeLocalizationError('SIFT',im_lion_1,im_lion_3,4,homography=None))
# Out:
# 2.2193740319051476
# 2.2193740319051476

# %% [markdown]
# # Descriptors

# %%
print('SIFT:')
siftP, siftR = computeDescriptors('SIFT',im_castle_1,im_castle_6,700) #500
print('\nORB:')
orbP, orbR = computeDescriptors('ORB',im_castle_1,im_castle_6,800) #700
#print('\nSURF:')
#surfP, surfR = computeKeypoints('SURF',im_castle_1,im_castle_6,50)
plt.figure(figsize=(12,8))
plt.plot(np.linspace(0,1,10),np.linspace(0,1,10),linestyle='dashed')
plt.scatter((1-np.array(siftR))[::-1],siftP,label='SIFT')
plt.scatter((1-np.array(orbR))[::-1],orbP,label='ORB')
# plt.plot(surfR,surfP,label='SURF')
plt.xlim(-0.01,1.01)
plt.ylim(-0.01,1.01)
plt.xlabel('Recall',fontsize=18)
plt.ylabel('Precision',fontsize=18)
plt.title('i_castle_1 / i_castle_6',fontsize=22)
plt.legend()
plt.show()
# Out:
# SIFT:
# 100.00%
# ORB:
# 96.87%100.00%

# %%
print(sklearn.metrics.auc((1-np.array(orbR))[::-1], orbP))
print(sklearn.metrics.auc((1-np.array(siftR))[::-1], siftP))
print(sklearn.metrics.auc(np.linspace(0,1,10), np.linspace(0,1,10)))
# Out:
# 0.848262
# 0.9808407137820169
# 0.5

# %%
print((1-np.array(siftR))[::-1][0],(1-np.array(siftR))[::-1][-1])
print((1-np.array(orbR))[::-1][0],(1-np.array(orbR))[::-1][-1])
# Out:
# 0.0 1.0
# 0.0 1.0

# %% [markdown]
# ### Scaling:
#     v_there

# %% [markdown]
# # Test code

# %%
im1 = cv2.imread(im_lion_1)
im1 = cv2.cvtColor(im1,cv2.COLOR_BGR2GRAY)
im2 = cv2.imread(im_lion_3)
im2 = cv2.cvtColor(im2,cv2.COLOR_BGR2GRAY)
detector = cv2.ORB_create()
kp1,_ = detector.detectAndCompute(im1, None)
kp2,_ = detector.detectAndCompute(im2, None)
kp1 = np.array(list(map(lambda x: [x.pt[0], x.pt[1]], kp1)))
kp2 = np.array(list(map(lambda x: [x.pt[0], x.pt[1]], kp2)))
eps = 1
neigh = NearestNeighbors(n_neighbors=1,radius=eps)
neigh = neigh.fit(kp1)
dist, idx = neigh.radius_neighbors(kp2, return_distance=True,sort_results=True)
print(dist)
# Out:
# [array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([0.95295105]) array([], dtype=float64)
#  array([1.]) array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([0.92813523]) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64) array([1.])
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([0.82231016]) array([], dtype=float64)
#  array([], dtype=float64) array([0.        , 0.82464185, 0.94402803])
#  array([], dtype=float64)
#  array([0.63245071, 0.65042523, 0.88543388, 1.        ])
#  array([0.99352764]) array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([0.59643883]) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([0.47264642, 0.90687406])
#  array([0.84853677]) array([], dtype=float64)
#  array([0.36359059, 0.53244332, 0.59058267]) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64) array([0.94731241])
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([0.35479754, 0.64575494, 0.86533942]) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64) array([0.33941902])
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([0.90951115]) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([0.82463445]) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([0.5951131]) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([0.86020281]) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([0.73507664]) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64) array([0.46091251])
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64) array([0.59532082])
#  array([0.54194572]) array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([0.85047547]) array([0.74250827])
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([0.90736614]) array([], dtype=float64)
#  array([], dtype=float64) array([0.5440651 , 0.64398867, 0.75895436])
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64) array([0.60306196])
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([0.86996648]) array([], dtype=float64)
#  array([], dtype=float64) array([0.84090674, 0.84090674])
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64) array([0.74448144])
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64) array([0.86213079])
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64) array([0.4203869])
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64) array([0.89896773])
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64) array([0.63379532])
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64) array([0.58651689])
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([0.99884061]) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([0.92733222]) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64)
#  array([0.41467285, 0.44172382, 0.75108234, 0.94999905])
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([0.63728287, 0.63730439]) array([0.]) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64) array([0.])
#  array([], dtype=float64) array([0.]) array([], dtype=float64)
#  array([0.49766541]) array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([0.        , 0.99237269])
#  array([], dtype=float64) array([], dtype=float64)
#  array([0.        , 0.43142472]) array([0.91767118])
#  array([0.        , 0.99656203])
#  array([0.        , 0.02858991, 0.45162737, 0.55687991])
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64) array([0.])
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64) array([0.])
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([0.]) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([0.]) array([0.]) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64) array([0.]) array([0.])
#  array([], dtype=float64) array([0.]) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([0.]) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64) array([0.])
#  array([], dtype=float64) array([0., 0.]) array([], dtype=float64)
#  array([0.59719849]) array([0.59719849]) array([], dtype=float64)
#  array([0.8445608]) array([], dtype=float64) array([], dtype=float64)
#  array([0.]) array([], dtype=float64) array([], dtype=float64)
#  array([0.59719849]) array([], dtype=float64) array([0.])
#  array([], dtype=float64) array([], dtype=float64)
#  array([], dtype=float64) array([], dtype=float64)]

# %%
recall = np.zeros(len(kp2))

for i_arr in idx:
    for i in i_arr:
        if recall[i] == 0:
            recall[i] = 1
            break

# %%
def closest_node_index(node, nodes):
    index = cdist([node], nodes).argmin()
    return index

final = []
for arr in kp2:
    i = closest_node_index(arr, kp1)
    final.append(kp1[i])
    kp1 = np.delete(kp1, i, axis=0)

# %%
final
# Out:
# [array([125., 184.]),
#  array([166.80000305, 211.20001221]),
#  array([137.3553009 , 110.48143768]),
#  array([286.84802246, 357.69604492]),
#  array([179.15908813, 353.34152222]),
#  array([260., 362.]),
#  array([126.00000763, 186.        ]),
#  array([246.34373474, 375.73641968]),
#  array([302.40002441, 297.21603394]),
#  array([109.44000244, 264.96002197]),
#  array([266., 361.]),
#  array([211.68000793, 275.04000854]),
#  array([126., 186.]),
#  array([495.67346191, 250.82272339]),
#  array([166.80000305, 208.80000305]),
#  array([497.6640625 , 252.97923279]),
#  array([442.80001831, 241.20001221]),
#  array([246.75843811, 375.32165527]),
#  array([431.30886841, 246.75843811]),
#  array([298.59848022, 295.61248779]),
#  array([578.88006592, 274.75201416]),
#  array([167.61601257, 167.61601257]),
#  array([212., 392.]),
#  array([224., 304.]),
#  array([286.55999756, 362.88000488]),
#  array([179.15908813, 349.36022949]),
#  array([237., 241.]),
#  array([224.40000916, 304.80001831]),
#  array([298., 296.]),
#  array([200.40000916, 331.20001221]),
#  array([141.6960144 , 136.51200867]),
#  array([143.42401123, 133.05601501]),
#  array([238., 186.]),
#  array([166.80000305, 162.        ]),
#  array([584.40002441, 276.        ]),
#  array([391.68002319, 361.44000244]),
#  array([434., 246.]),
#  array([430.27203369, 245.37602234]),
#  array([143.07841492, 132.7104187 ]),
#  array([392.40002441, 362.40002441]),
#  array([208., 393.]),
#  array([273.02401733, 316.22402954]),
#  array([331.44430542, 244.85075378]),
#  array([430.56002808, 244.80000305]),
#  array([328.32003784, 240.1920166 ]),
#  array([336.96002197, 246.24000549]),
#  array([300.        , 240.00001526]),
#  array([263.76199341, 388.17800903]),
#  array([179.15908813, 347.56863403]),
#  array([234.00001526, 300.        ]),
#  array([236.40000916, 240.00001526]),
#  array([216.00001526, 325.20001221]),
#  array([158.25720215,  92.56552887]),
#  array([109.20000458, 266.40002441]),
#  array([167., 185.]),
#  array([338., 211.]),
#  array([167., 211.]),
#  array([ 34., 300.]),
#  array([187.20001221, 410.40002441]),
#  array([406.80001831, 211.20001221]),
#  array([434.88000488, 234.72001648]),
#  array([355.33218384, 203.04696655]),
#  array([ 70.80000305, 418.80001831]),
#  array([264.3840332 , 387.07202148]),
#  array([236.16000366, 240.48001099]),
#  array([ 70., 420.]),
#  array([235., 300.]),
#  array([168., 209.]),
#  array([286.55999756, 357.12002563]),
#  array([235.00802612, 240.1920166 ]),
#  array([408., 211.]),
#  array([171.07202148, 160.70401001]),
#  array([430., 245.]),
#  array([397.73318481, 200.65818787]),
#  array([188.35202026, 392.25604248]),
#  array([273.6000061, 315.6000061]),
#  array([443., 240.]),
#  array([408., 248.]),
#  array([301.08679199, 298.59848022]),
#  array([166.80000305, 186.        ]),
#  array([298.59844971, 244.68482971]),
#  array([429.6000061 , 244.80000305]),
#  array([275., 315.]),
#  array([414., 248.]),
#  array([433.72802734, 388.80004883]),
#  array([412.80001831, 247.20001221]),
#  array([182.74227905, 326.06954956]),
#  array([327.62884521, 240.53762817]),
#  array([237.6000061, 186.       ]),
#  array([166.71748352, 186.6240387 ]),
#  array([442.08001709, 240.48001099]),
#  array([176., 299.]),
#  array([232.2432251 , 240.53762817]),
#  array([397.13598633, 200.06097412]),
#  array([171.36000061, 159.8400116 ]),
#  array([412.99203491, 245.37602234]),
#  array([413.2800293 , 244.80000305]),
#  array([ 32., 300.]),
#  array([176.40000916, 300.        ]),
#  array([167.61601257, 186.62402344]),
#  array([167.04000854, 185.76000977]),
#  array([167.96162415, 186.62402344]),
#  array([414., 240.]),
#  array([302.74563599, 398.1312561 ]),
#  array([177.12001038, 299.52001953]),
#  array([410.57284546, 244.68482971]),
#  array([385.92001343, 210.24000549]),
#  array([184., 221.]),
#  array([136.8576355 , 134.36930847]),
#  array([410.57290649, 243.85542297]),
#  array([174., 148.]),
#  array([171., 145.]),
#  array([180.40322876, 354.58566284]),
#  array([273.6000061 , 315.36001587]),
#  array([189.6000061, 393.6000061]),
#  array([216., 325.]),
#  array([202.17602539, 212.54402161]),
#  array([298.08001709, 244.80000305]),
#  array([435.95379639, 232.90681458]),
#  array([218.88000488, 309.6000061 ]),
#  array([290.30401611, 362.8800354 ]),
#  array([210.81602478, 274.75201416]),
#  array([219.6000061 , 301.20001221]),
#  array([203.04000854, 213.12001038]),
#  array([265.4208374 , 387.76324463]),
#  array([202.80000305, 212.40000916]),
#  array([235.00802612, 184.89601135]),
#  array([193.49182129, 347.56863403]),
#  array([237.6000061 , 185.76000977]),
#  array([215., 221.]),
#  array([177.98402405, 300.67202759]),
#  array([217.72802734, 307.58401489]),
#  array([296.64001465, 296.64001465]),
#  array([191.10302734, 349.36022949]),
#  array([429.23526001, 236.39042664]),
#  array([212.54402161, 304.12802124]),
#  array([178.56001282, 295.20001221]),
#  array([204.24136353, 333.23590088]),
#  array([428.54403687, 236.73602295]),
#  array([398.13128662, 199.06564331]),
#  array([201.13922119, 333.84963989]),
#  array([277.69659424, 319.50036621]),
#  array([290.30404663, 362.88006592]),
#  array([181.4400177 , 354.24002075]),
#  array([209., 199.]),
#  array([209.0880127 , 193.53601074]),
#  array([296.64001465, 388.80001831]),
#  array([178.80000305, 296.40002441]),
#  array([200.65818787, 272.32180786]),
#  array([216.00001526, 308.16000366]),
#  array([297.21603394, 245.37602234]),
#  array([164.22915649,  77.13793945]),
#  array([385.68966675, 209.43362427]),
#  array([357., 207.]),
#  array([246., 329.]),
#  array([385.34402466, 209.0880127 ]),
#  array([217.72802734, 306.89285278]),
#  array([335.92324829, 246.75843811]),
#  array([290.30404663, 393.98406982]),
#  array([187., 160.]),
#  array([257.47201538, 305.85601807]),
#  array([205., 331.]),
#  array([430.47946167, 231.41381836]),
#  array([295., 391.]),
#  array([141.83427429, 131.8809967 ]),
#  array([140.34127808, 131.3833313 ]),
#  array([357.69604492, 205.63201904]),
#  array([397.44000244, 197.28001404]),
#  array([234.3168335 , 248.83203125]),
#  array([409.07992554, 241.86477661]),
#  array([136.16090393, 111.07863617]),
#  array([ 70.56000519, 417.6000061 ]),
#  array([ 67.68000031, 421.92001343]),
#  array([299.52001953, 240.48001099]),
#  array([216.48388672, 306.06344604]),
#  array([327.6000061 , 240.00001526]),
#  array([333.43496704, 246.34373474]),
#  array([179., 297.]),
#  array([390.5668335 , 200.65818787]),
#  array([233.2800293 , 248.83203125]),
#  array([254.40000916, 324.        ]),
#  array([228.96000671, 244.80000305]),
#  array([203.04696655, 331.44430542]),
#  array([412.06591797, 240.07318115]),
#  array([295.48803711, 297.21603394]),
#  array([139.74409485, 128.99455261]),
#  array([429.98181152, 229.9208374 ]),
#  array([478.80001831, 381.6000061 ]),
#  array([240.00001526, 300.        ]),
#  array([181.4400177 , 311.04003906]),
#  array([179.15908813, 297.40408325]),
#  array([241.20001221, 325.20001221]),
#  array([182.14508057, 304.57043457]),
#  array([328.32000732, 240.48001099]),
#  array([243.36001587, 299.52001953]),
#  array([182.74227905, 308.15362549]),
#  array([199., 166.]),
#  array([383.2013855 , 211.50724792]),
#  array([196.57733154, 283.66854858]),
#  array([188.69763184, 304.81924438]),
#  array([256., 323.]),
#  array([254., 323.]),
#  array([298.59848022, 388.17800903]),
#  array([241., 325.]),
#  array([244.80000305, 324.        ]),
#  array([207., 325.]),
#  array([211.50724792, 303.57510376]),
#  array([244.80000305, 324.        ]),
#  array([243., 323.]),
#  array([233.90213013, 186.6240387 ]),
#  array([210.00001526, 192.        ]),
#  array([296.40002441, 390.00003052]),
#  array([211.50723267, 302.74563599]),
#  array([202., 163.]),
#  array([ 73.44000244, 401.76000977]),
#  array([228.96000671, 233.28001404]),
#  array([297.21603394, 388.80004883]),
#  array([296.11013794, 243.85542297]),
#  array([214.80000305, 277.20001221]),
#  array([273.715271  , 313.52838135]),
#  array([273.71524048, 313.11364746]),
#  array([387.76324463, 203.21282959]),
#  array([ 73.20000458, 402.00003052]),
#  array([336.96002197, 245.37602234]),
#  array([333.23590088, 243.65637207]),
#  array([202.80000305, 144.        ]),
#  array([197.07499695, 283.07138062]),
#  array([418.03787231, 232.90681458]),
#  array([388.17800903, 201.55397034]),
#  array([322.48635864, 232.90681458]),
#  array([230.40000916, 213.12001038]),
#  array([224.40000916, 248.40000916]),
#  array([146.81091309,  99.53282166]),
#  array([257.12643433, 304.81924438]),
#  array([279.4881897 , 315.32000732]),
#  array([224., 247.]),
#  array([145.15202332,  99.53281403]),
#  array([146.31326294,  95.55151367]),
#  array([138.93121338,  91.23841095]),
#  array([319.50036621, 232.90681458]),
#  array([300., 241.]),
#  array([397.44003296, 196.99201965]),
#  array([141.6000061,  90.       ]),
#  array([223.20001221, 247.68000793]),
#  array([142.,  90.]),
#  array([212.40000916, 301.20001221]),
#  array([197.07499695, 283.66854858]),
#  array([243.6000061 , 301.20001221]),
#  array([211.68000793, 300.96002197]),
#  array([204.48001099, 300.96002197]),
#  array([201.6000061 , 302.40002441]),
#  array([199.06562805, 282.00964355]),
#  array([201.6000061 , 300.96002197]),
#  array([200.44801331, 283.39202881]),
#  array([244., 300.]),
#  array([300.67202759, 387.76324463]),
#  array([429.98181152, 229.32363892]),
#  array([233.90213013, 176.67076111]),
#  array([419.23226929, 232.90681458]),
#  array([420.52618408, 231.41381836]),
#  array([296.52484131, 396.05764771]),
#  array([300.96002197, 396.00003052]),
#  array([139.96801758,  89.85601044]),
#  array([298.59844971, 306.89285278]),
#  array([358.73284912, 203.21282959]),
#  array([163.81442261,  76.7232132 ]),
#  array([217., 281.]),
#  array([129.6000061 ,  89.85601044]),
#  array([ 71., 405.]),
#  array([297.40408325, 300.98727417]),
#  array([217.97689819, 250.82272339]),
#  array([217.20001221, 282.        ]),
#  array([230.40000916, 177.12001038]),
#  array([321., 227.]),
#  array([320.99334717, 231.41381836]),
#  array([232., 178.]),
#  array([226.80000305, 277.20001221]),
#  array([420.94085693, 230.16963196]),
#  array([139.34594727,  89.57954407]),
#  array([221.46052551, 251.32037354]),
#  array([295.61248779, 304.57043457]),
#  array([ 69.12000275, 404.64001465]),
#  array([293.82092285, 243.65637207]),
#  array([222.91201782, 248.83203125]),
#  array([272.32180786, 308.15362549]),
#  array([314., 244.]),
#  array([421.63204956, 229.82402039]),
#  array([275., 308.]),
#  array([220.96287537, 259.78067017]),
#  array([321.40805054, 230.16963196]),
#  array([274.80001831, 307.20001221]),
#  array([221.46052551, 258.78533936]),
#  array([421.92001343, 228.96000671]),
#  array([378., 243.]),
#  array([222.15727234, 261.57226562]),
#  array([302., 396.]),
#  array([131.8809967 ,  89.57954407]),
#  array([247., 300.]),
#  array([302.40002441, 397.20001221]),
#  array([232.80000305, 174.        ]),
#  array([259., 300.]),
#  array([141.12001038,  89.28000641]),
#  array([334.43029785, 364.29016113]),
#  array([247.20001221, 300.        ]),
#  array([241.86477661, 283.66854858]),
#  array([130.63682556,  89.16481018]),
#  array([388.17803955, 200.06097412]),
#  array([129.6000061 ,  89.28000641]),
#  array([ 68.42881012, 404.35205078]),
#  array([162.,  78.]),
#  array([273.6000061 , 306.72000122]),
#  array([335.23202515, 366.33602905]),
#  array([ 68.40000153, 405.6000061 ]),
#  array([233., 174.]),
#  array([308.96643066, 400.2048645 ]),
#  array([225., 269.]),
#  array([250.90563965, 302.74563599]),
#  array([243.36001587, 277.92001343]),
#  array([380.16000366, 233.28001404]),
#  array([321.6000061 , 229.20001221]),
#  array([164.16001892,  76.03200531]),
#  array([243.64802551, 279.93603516]),
#  array([249.6000061 , 301.20001221]),
#  array([217.97689819, 101.52348328]),
#  array([ 68., 405.]),
#  array([218.97221375, 102.02114105]),
#  array([ 67.39200592, 404.35205078]),
#  array([243.65637207, 283.07138062]),
#  array([ 64.80000305, 400.32000732]),
#  array([221.184021  , 103.68000793]),
#  array([244.68482971, 282.00964355]),
#  array([243.85542297, 283.66854858]),
#  array([252.2880249 , 302.40002441]),
#  array([ 71., 433.]),
#  array([295.61248779, 241.86477661]),
#  array([253., 300.]),
#  array([383., 225.]),
#  array([222.00001526, 104.40000153]),
#  array([254.40591431, 286.65454102]),
#  array([275.90499878, 300.98727417]),
#  array([260., 298.]),
#  array([297.21603394, 305.85601807]),
#  array([169.,  64.]),
#  array([219.80163574, 101.60641479]),
#  array([262., 299.]),
#  array([312.        , 400.80001831]),
#  array([262.80001831, 301.20001221]),
#  array([313.92001343, 400.32000732]),
#  array([314., 400.]),
#  array([262.80001831, 294.        ]),
#  array([221.76000977, 103.68000793]),
#  array([263., 294.]),
#  array([267.6000061, 300.       ]),
#  array([268., 300.]),
#  array([336.        , 364.80001831]),
#  array([304.57043457, 232.90681458]),
#  array([231.6000061, 111.6000061]),
#  array([224.64001465,  88.12800598]),
#  array([ 64.80000305, 400.80001831]),
#  array([304.57046509, 232.90681458]),
#  array([376., 242.]),
#  array([271.20001221, 302.40002441]),
#  array([321.40802002, 229.82402039]),
#  array([270.72000122, 300.96002197]),
#  array([273.715271  , 298.59848022]),
#  array([313.20001221, 244.80000305]),
#  array([312.48001099, 237.6000061 ]),
#  array([304.81924438, 230.16963196]),
#  array([271., 301.]),
#  array([232., 111.]),
#  array([306.06344604, 231.41381836]),
#  array([274.71060181, 298.59848022]),
#  array([296.11013794, 306.06344604]),
#  array([ 63.93600464, 400.89602661]),
#  array([298., 309.]),
#  array([314.40002441, 400.80001831]),
#  array([375.6000061 , 242.40000916]),
#  array([ 57.02400589, 402.62402344]),
#  array([ 67., 422.]),
#  array([314.49603271, 400.89602661]),
#  array([226.43717957,  89.57954407]),
#  array([315.18725586, 402.27844238]),
#  array([ 42.        , 397.20001221]),
#  array([306., 227.]),
#  array([397.20001221, 196.80000305]),
#  array([374., 237.]),
#  array([373.24804688, 235.00802612]),
#  array([316., 407.]),
#  array([ 67.20000458, 422.40002441]),
#  array([335.92327881, 365.78311157]),
#  array([305.27999878, 228.96000671]),
#  array([305.85601807, 229.82402039]),
#  array([306.        , 229.20001221]),
#  array([226.02243042,  89.16481018]),
#  array([311.04003906, 236.73602295]),
#  array([307., 229.]),
#  array([312., 238.]),
#  array([379.81729126, 218.57409668]),
#  array([321.12002563, 228.96000671]),
#  array([311.04000854, 234.72001648]),
#  array([326., 404.]),
#  array([326.59204102, 404.35205078]),
#  array([224.64001465,  87.84000397]),
#  array([337., 364.]),
#  array([233.90213013,  89.57954407]),
#  array([236.16000366,  89.28000641]),
#  array([ 67., 424.]),
#  array([234.3168335 ,  89.16481018]),
#  array([235.00802612,  88.12800598]),
#  array([335.92324829, 367.0272522 ]),
#  array([336.96002197, 365.76000977]),
#  array([310.54241943, 232.90681458]),
#  array([311.73681641, 232.90681458]),
#  array([ 53.56800461, 406.08004761]),
#  array([313.11364746, 234.3168335 ]),
#  array([328., 403.]),
#  array([ 53.28000259, 406.08001709]),
#  array([339., 370.]),
#  array([313.52838135, 231.41381836]),
#  array([338.41159058, 375.73641968]),
#  array([339.84002686, 371.52001953]),
#  array([339.6000061, 372.       ]),
#  array([236.40000916,  88.80000305]),
#  array([340.41604614, 373.24804688]),
#  array([370.26211548, 235.89279175]),
#  array([340.07043457, 377.39526367]),
#  array([237.,  89.]),
#  array([232.,  75.]),
#  array([ 67.20000458, 424.80001831]),
#  array([398., 196.]),
#  array([ 52.80000305, 408.00003052]),
#  array([341.27999878, 377.2800293 ]),
#  array([353., 175.]),
#  array([364.32000732, 155.52000427]),
#  array([373.24807739, 228.92549133]),
#  array([345.8765564 , 370.75976562]),
#  array([346.37423706, 370.26211548]),
#  array([328.80001831, 404.40002441]),
#  array([337.20001221, 398.40002441]),
#  array([ 49.20000076, 405.6000061 ]),
#  array([364.29016113, 220.96287537]),
#  array([373.24810791, 226.93484497]),
#  array([338., 398.]),
#  array([372.65090942, 225.74046326]),
#  array([372.65090942, 207.82455444]),
#  array([339.6000061, 399.6000061]),
#  array([350.7840271 , 400.89602661]),
#  array([364.60803223, 155.52001953]),
#  array([364.80001831, 156.        ]),
#  array([ 69., 432.]),
#  array([365., 156.]),
#  array([ 46.08000183, 404.64001465]),
#  array([380.71304321, 206.53060913]),
#  array([370.08001709, 145.44000244]),
#  array([351.36001587, 401.76000977]),
#  array([ 68.40000153, 432.00003052]),
#  array([ 47.52000046, 407.52001953]),
#  array([382.20605469, 209.01893616]),
#  array([350.43844604, 404.35205078]),
#  array([ 47., 409.]),
#  array([ 54.00000381, 424.80001831]),
#  array([375., 125.]),
#  array([376.80001831, 151.20001221]),
#  array([377., 151.]),
#  array([378.72000122, 149.76000977]),
#  array([ 46.80000305, 409.20001221]),
#  array([379., 150.]),
#  array([379.46884155, 203.21282959]),
#  array([ 54., 425.]),
#  array([383.40045166, 207.82455444]),
#  array([379.20001221, 150.        ]),
#  array([373., 405.]),
#  array([393.6000061, 177.6000061]),
#  array([419., 390.]),
#  array([392., 176.]),
#  array([393.12002563, 177.12001038]),
#  array([395., 177.]),
#  array([393.6000061 , 175.20001221]),
#  array([394., 175.]),
#  array([421., 392.]),
#  array([423.01449585, 388.17800903]),
#  array([421.92001343, 390.24002075]),
#  array([421.63204956, 390.52804565]),
#  array([421.20001221, 391.20001221]),
#  array([427.16165161, 389.83685303]),
#  array([427.9911499 , 388.17800903]),
#  array([433.38244629, 389.83685303]),
#  array([418., 409.]),
#  array([470., 427.]),
#  array([496.80001831, 385.92001343]),
#  array([470., 429.]),
#  array([498.00003052, 386.40002441]),
#  array([492.48001099, 396.00003052]),
#  array([493.20001221, 397.20001221]),
#  array([495.36001587, 394.56002808]),
#  array([499., 427.]),
#  array([514.08001709, 397.44000244]),
#  array([516.96002197, 397.44000244]),
#  array([517.20001221, 398.40002441]),
#  array([546.        , 400.80001831])]

# %%
res
# Out:
# (array([array([4.24264069]), array([], dtype=float64), array([4.87523203]),
#         array([3.68823727, 3.21991605, 2.57590009, 3.21994335, 3.68828016]),
#         array([], dtype=float64), array([1.]),
#         array([3.60555128, 1.41420817, 1.41421356]),
#         array([], dtype=float64), array([3.15315841, 3.9337533 ]),
#         array([], dtype=float64), array([5.]), array([], dtype=float64),
#         array([5.        , 3.16227042, 3.16227766]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([0.        , 0.89444766]), array([1.]),
#         array([], dtype=float64),
#         array([3.49581345, 2.56123206, 1.41421356, 2.3866196 ]),
#         array([2.82842712, 2.68328157, 4.3642796 , 4.76386539, 4.55618849]),
#         array([], dtype=float64), array([3.        , 3.25216814]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([2.23606798, 2.44130762, 2.24891469, 4.09129463]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([3.9761167 , 5.        , 3.75765592, 2.9588213 ]),
#         array([4.66701099]), array([], dtype=float64),
#         array([0.83234643, 1.3999939 , 0.70655425, 1.4727897 ]),
#         array([2.82255435, 2.04429327, 4.85620639, 2.41958128]),
#         array([1.52587891e-05, 6.78816468e-01, 1.00000000e+00, 4.76735306e+00,
#         4.88998698e+00]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64),
#         array([2.99812909, 1.59999084, 1.41421356, 1.90157752]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([1.41421356]), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([3.09353048, 1.70080771]),
#         array([1.]), array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64),
#         array([3.70902204, 2.56125589, 3.16227766, 3.08804809]),
#         array([3.60555128, 2.54558873]), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([4.95176761, 4.10495954]),
#         array([], dtype=float64),
#         array([1.        , 4.43300728, 3.66935919, 3.88331297, 4.77719599,
#         5.        ]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([3.22300644, 2.91998646, 2.70635487]),
#         array([], dtype=float64),
#         array([2.15627708, 4.09320694, 4.79230865, 2.        , 1.97989036,
#         3.70171105, 3.6774246 , 2.12288428]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([4.76820116, 3.27999059, 1.4421985 , 2.81091664, 0.        ]),
#         array([], dtype=float64),
#         array([2.54022623, 3.02653326, 2.82616259, 2.49018692, 3.91005491]),
#         array([1.        , 4.11508012, 1.07703069, 1.30290863, 3.65768723]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([4.30814261, 4.84314825]),
#         array([4.6749612]), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([0.        , 2.23607139, 2.23606798]),
#         array([4.85369829, 1.93546604, 0.        ]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64),
#         array([2.3999939 , 3.39411471, 3.40586831, 3.60554197]),
#         array([3.32827374, 3.07349611, 2.87932044]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([3.68823727, 3.21991605, 2.57590009, 3.21994335, 3.68828016]),
#         array([], dtype=float64), array([0.89444766, 0.        ]),
#         array([], dtype=float64), array([0.89442719]),
#         array([], dtype=float64),
#         array([4.81662516, 4.79998779, 4.55999756, 4.51428509]),
#         array([], dtype=float64),
#         array([1.44221966, 1.69705196, 1.53675163, 3.79319214]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([1.23571767, 2.73640603, 2.3999939 , 0.89310847, 0.54730208,
#         4.76933877]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([2.68328157, 3.45774477]),
#         array([2.89992164, 3.00665806, 2.68328157, 4.60130961, 3.26209302,
#         2.51162309]),
#         array([0.44724089]), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64),
#         array([3.56950818, 3.21165142, 1.44000244, 2.87998962, 2.65523   ]),
#         array([4.79998779, 4.34657482, 3.80000305, 2.84293251, 4.00290624,
#         1.91998291, 1.40627455]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([1.28060531]), array([3.22488796]), array([], dtype=float64),
#         array([2.82841634, 2.68326793, 4.36429454, 4.76387539, 4.5562028 ]),
#         array([3.03349494, 2.17329499, 4.28996848, 2.07963497]),
#         array([3.0528759]), array([], dtype=float64),
#         array([3.68579742, 2.59821786]), array([], dtype=float64),
#         array([4.70650765, 2.96862628]), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([1.61245344]), array([3.53836155, 2.68328157]),
#         array([2.59908152, 1.19999695, 1.16618043, 1.51789424]),
#         array([4.86622608, 4.01824641, 3.35953001, 2.4475405 , 0.        ,
#         1.83406909, 1.4421985 ]),
#         array([3.92781663]), array([], dtype=float64),
#         array([], dtype=float64),
#         array([0.        , 0.67880568, 0.99998474, 4.76734709, 4.88997236]),
#         array([], dtype=float64),
#         array([0.86533095, 0.        , 0.7451914 , 0.53838587]),
#         array([4.5052916]), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([2.8284487]), array([4.20476327]), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([0.82462335, 1.69705735, 1.69705196]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([2.68330887, 3.25578005]), array([], dtype=float64),
#         array([], dtype=float64), array([4.21900318]),
#         array([], dtype=float64),
#         array([3.20199489, 3.59999084, 3.48322238, 3.06251372, 4.04264851]),
#         array([3.79474284, 2.68328157, 1.84392379]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([0.97651305]), array([3.72235723]),
#         array([4.7235875 , 2.87997437, 2.32188875, 2.88000488, 4.72363029]),
#         array([], dtype=float64), array([1.07704203]),
#         array([], dtype=float64),
#         array([4.37165588, 2.88513978, 4.31999207, 2.03647098, 2.65520682]),
#         array([4.78832764, 4.61648995]), array([], dtype=float64),
#         array([1.72695411, 4.35693095, 1.67999268, 1.44000244, 2.65521013]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64),
#         array([4.55367308, 4.25750603, 3.83461277, 1.03839545, 2.18464079,
#         0.        , 4.40996321, 0.53107182]),
#         array([], dtype=float64),
#         array([2.03647098, 4.00101132, 3.36238682, 1.87446961, 3.62249429,
#         1.03840391]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64),
#         array([2.3039856 , 1.44000244, 3.76983266, 1.38715198]),
#         array([4.21496354]), array([], dtype=float64),
#         array([], dtype=float64),
#         array([3.60759583, 3.12208521, 1.44000244, 1.07332355, 0.91071821,
#         1.90156212]),
#         array([], dtype=float64),
#         array([4.31999207, 4.85368773, 4.60798645, 4.31804871, 3.12471026]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([2.00357041, 0.91071821]),
#         array([4.99409327, 4.15359873]),
#         array([4.27307862, 3.11950473, 4.07294196]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64),
#         array([0.        , 0.86533095, 0.28799439, 0.69355952]),
#         array([0.67880568, 0.        , 0.70765092, 4.14564592, 4.79798901,
#         4.55367308, 4.30462443]),
#         array([], dtype=float64), array([3.4002585 , 4.67568676]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([4.61648202, 2.57991339, 2.68327748, 4.34260064, 4.6438532 ]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([3.96767708, 4.61648202, 3.49657554, 2.32191146, 2.07727716,
#         3.5549422 , 3.21994335, 3.91724473]),
#         array([2.30428104, 1.29947285, 1.43998718, 2.03647098, 0.64398867]),
#         array([0.38639184, 1.44000244, 1.39943955, 1.18771103, 1.93196601]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([1.20001831, 1.96977001]),
#         array([], dtype=float64),
#         array([1.73066614, 1.73296838, 3.47994764, 4.33623374, 2.03647314,
#         1.43998718]),
#         array([4.97575304]), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([1.43997192]), array([], dtype=float64), array([4.1295603]),
#         array([1.28807839]), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([0.28799439, 0.7451914 , 0.        , 0.77278367]),
#         array([2.86974843, 2.96085483, 2.73220771, 3.86391837]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([3.8600786 , 0.        , 1.8802203 , 1.03839545, 3.80578196,
#         1.545581  ]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([4.89601135, 4.88751525, 3.16811536]),
#         array([2.85734225, 2.51599381, 0.64400232, 1.83406909, 0.        ,
#         2.81091664]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([1.72799683, 0.86401367, 3.60611213, 1.0928522 ]),
#         array([1.03840391, 3.18626209, 2.32438289, 0.84921629, 2.78286737,
#         0.        ]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64),
#         array([4.88752388, 4.19143396, 3.025788  , 3.91724473]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([1.96469222, 0.69116211, 1.82147985, 2.32191146, 0.        ]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([1.0928522, 0.       ]), array([], dtype=float64),
#         array([3.86394566, 3.86393202]),
#         array([4.42070792, 1.09548832, 1.63269663]),
#         array([1.72798157, 3.28370812, 2.93154848, 1.17499677, 0.        ,
#         4.38957928]),
#         array([4.2194098 , 4.17613926]), array([], dtype=float64),
#         array([3.07284052, 4.4043918 ]), array([], dtype=float64),
#         array([], dtype=float64), array([1.16576972]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([1.05612555]), array([], dtype=float64),
#         array([], dtype=float64), array([0.98488622, 1.84659695]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([4.9249604 , 4.90817216]),
#         array([], dtype=float64),
#         array([1.0732826 , 0.64397502, 1.32962709, 3.72790888, 4.63157584,
#         4.68828953, 4.50608432]),
#         array([2.10221292, 3.42656208, 2.53082676, 3.62290229, 1.09563221,
#         2.44375655]),
#         array([4.39007159, 4.25472982, 4.61697735, 0.93371005, 1.02609161]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([2.94182853]), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64),
#         array([2.93251433, 4.30194214, 3.80698956, 2.41818343, 1.24609485,
#         3.15844906, 4.63671569, 4.12470001, 4.984299  ]),
#         array([], dtype=float64), array([0.82084041, 0.45158134]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([1.49525965, 0.        , 2.14282456, 2.94206243, 0.69116211]),
#         array([], dtype=float64), array([4.24742174]),
#         array([4.63671569, 4.63670204]), array([], dtype=float64),
#         array([], dtype=float64), array([2.70047643, 3.32522775]),
#         array([], dtype=float64),
#         array([0.86060951, 1.15344801, 0.81572592, 4.98862286, 4.63670204]),
#         array([2.8567481 , 2.90301514, 2.0736084 , 3.34130397, 2.27052562,
#         2.78631495, 3.64511511]),
#         array([], dtype=float64),
#         array([0.69355952, 0.53838587, 0.77278367, 0.        ]),
#         array([], dtype=float64),
#         array([4.89268514, 3.88727364, 4.8688519 ]),
#         array([1.72799683, 4.10422341, 4.86828396, 1.15916869, 2.52260232,
#         0.        ]),
#         array([4.70192123, 2.58327451, 3.75548071]),
#         array([], dtype=float64), array([4.41479753]),
#         array([], dtype=float64),
#         array([2.96396498, 0.97749399, 0.92730492, 1.55943471, 2.89290514,
#         2.0736084 ]),
#         array([], dtype=float64), array([4.58070039, 4.56264396]),
#         array([], dtype=float64), array([0.       , 1.0928522]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([3.6010955 , 4.98557908]), array([], dtype=float64),
#         array([1.52203181, 1.68754209, 1.48648191, 3.473244  ]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([1.11284097, 2.05191519]),
#         array([4.756729  , 3.12535695, 4.83642706, 2.48831177, 2.53759065]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64),
#         array([4.95515138, 0.42796364, 1.3053574 ]),
#         array([4.04519213, 2.83076584, 1.91431174, 2.85984042]),
#         array([4.79798901, 4.82539814, 2.05190853, 1.8802203 , 0.        ,
#         2.18464079, 2.29785269, 2.62290125]),
#         array([4.87825446, 0.        , 2.48830566, 0.82940674, 2.86718423,
#         4.01824641, 2.85734225, 4.06625583]),
#         array([3.53025541, 1.57374654, 2.48834229, 4.99387231]),
#         array([3.78142049]), array([], dtype=float64),
#         array([], dtype=float64), array([1.11281368, 1.73827053]),
#         array([1.82987351, 4.92661458]), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([1.79432851]), array([4.25204973, 4.81915161]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([1.09119125, 1.54480908]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([3.91247521, 3.9124655 ]),
#         array([2.9977052 , 2.52260734, 4.04987631, 3.15007628, 2.48831177,
#         3.23974336]),
#         array([4.4818999 , 4.86330729, 4.17766849, 1.49525965, 2.56576819]),
#         array([], dtype=float64),
#         array([0.82946777, 2.62078209, 2.53733768, 0.        , 1.17499677]),
#         array([], dtype=float64),
#         array([3.91806839, 4.72431115, 4.97663879, 3.97847393, 2.48834229,
#         3.54335215, 4.6103621 , 4.19752956]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([2.48830566, 0.        , 3.19084775, 3.48223565]),
#         array([], dtype=float64),
#         array([4.54200685, 4.25769819, 2.46231244, 3.25174196, 4.14633336,
#         3.58869088]),
#         array([], dtype=float64),
#         array([1.60188497, 3.5434293 , 4.92462488, 1.54180793, 1.43859198,
#         3.14754134, 4.22280941, 1.71139846]),
#         array([], dtype=float64),
#         array([4.76734709, 4.14564592, 4.47192374, 0.        , 3.8600786 ,
#         2.05190853, 3.83461277, 2.53367702, 4.10714841]),
#         array([2.41875593, 2.98599243, 1.45314241, 1.60836818]),
#         array([], dtype=float64),
#         array([2.1532213 , 0.        , 2.48831787, 4.86828396]),
#         array([4.21673973, 3.10188016, 2.06825254, 3.05112165]),
#         array([3.38433192, 0.59716797, 2.59125029, 0.49766541, 0.        ]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([4.26621483, 2.98599243, 0.        , 4.26014923, 2.11140471,
#         3.3363795 , 3.62529489]),
#         array([], dtype=float64), array([3.58872531, 4.47857793]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([4.92227304, 4.22280941, 4.66140632]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([0.        , 1.33537641]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64),
#         array([4.02717223, 3.58319092, 2.39086602]),
#         array([], dtype=float64), array([1.04773452]),
#         array([4.10198427, 0.        , 2.1532213 , 4.53257538, 2.69472549,
#         4.10422341]),
#         array([], dtype=float64),
#         array([2.53367702, 3.80578196, 2.29785269, 4.40996321, 0.        ,
#         4.88697125]),
#         array([], dtype=float64),
#         array([4.06625583, 3.48223565, 4.84732586, 4.88025733, 0.        ,
#         1.93546604]),
#         array([3.67390062, 3.2098965 , 3.93426849]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64),
#         array([4.17662043, 0.        , 2.98599243, 3.8112996 , 2.11142629,
#         2.94192404, 3.26595073]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([0.        , 4.49958347, 4.54810012]),
#         array([2.25909141, 2.15320437, 2.92080116, 3.89846279]),
#         array([], dtype=float64), array([3.5831604]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([], dtype=float64),
#         array([], dtype=float64), array([4.55415461]),
#         array([], dtype=float64), array([], dtype=float64),
#         array([4.34766327, 3.58318329]), array([], dtype=float64)],
#        dtype=object),
#  array([array([52]), array([], dtype=int64), array([438]),
#         array([319, 228, 330, 220, 384]), array([], dtype=int64),
#         array([12]), array([ 52, 146,  61]), array([], dtype=int64),
#         array([327, 428]), array([], dtype=int64), array([25]),
#         array([], dtype=int64), array([ 52, 146,  61]),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64), array([ 80, 162]),
#         array([25]), array([], dtype=int64), array([324, 197,  42, 239]),
#         array([ 80, 162, 350, 199, 291]), array([], dtype=int64),
#         array([161, 364]), array([], dtype=int64), array([], dtype=int64),
#         array([ 63, 149, 240, 315]), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([269,  56, 160, 313]), array([453]),
#         array([], dtype=int64), array([259, 158, 318, 387]),
#         array([293, 251, 402, 345]), array([156, 266,  79, 456, 368]),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([324, 197,  42, 239]),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64), array([50]),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64), array([467, 222]),
#         array([50]), array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([324, 197,  42, 239]),
#         array([ 73, 179]), array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64), array([160, 313]),
#         array([], dtype=int64), array([ 75, 409, 346, 191, 294,  53]),
#         array([], dtype=int64), array([], dtype=int64),
#         array([314, 243, 368]), array([], dtype=int64),
#         array([269, 388, 478,  56, 160, 426, 464, 313]),
#         array([], dtype=int64), array([], dtype=int64),
#         array([346, 242, 191, 294,  53]), array([], dtype=int64),
#         array([259, 158, 318, 387, 453]), array([ 63, 427, 149, 240, 315]),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([197, 239]), array([486]),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([ 52, 146,  61]),
#         array([242, 473,  51]), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([150, 187,  14,   1]), array([314, 243, 368]),
#         array([], dtype=int64), array([], dtype=int64),
#         array([319, 228, 330, 220, 384]), array([], dtype=int64),
#         array([ 80, 162]), array([], dtype=int64), array([12]),
#         array([], dtype=int64), array([ 63, 149, 240, 315]),
#         array([], dtype=int64), array([ 63, 149, 240, 315]),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([371, 248, 132, 415, 296, 416]), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([161, 364]),
#         array([269,  56, 160, 426, 464, 313]), array([25]),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([416, 350, 221, 199, 291]),
#         array([156, 266,  79, 314, 419, 243, 368]), array([], dtype=int64),
#         array([], dtype=int64), array([50]), array([12]),
#         array([], dtype=int64), array([ 80, 162, 350, 199, 291]),
#         array([293, 251, 402, 345]), array([25]), array([], dtype=int64),
#         array([370, 329]), array([], dtype=int64), array([467, 222]),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([50]), array([ 73, 179]),
#         array([324, 197,  42, 239]),
#         array([ 75, 409, 346, 242, 191, 294,  53]), array([438]),
#         array([], dtype=int64), array([], dtype=int64),
#         array([156, 266,  79, 456, 368]), array([], dtype=int64),
#         array([259, 158, 318, 387]), array([453]), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64), array([12]),
#         array([42]), array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([ 52, 146,  61]),
#         array([], dtype=int64), array([], dtype=int64), array([181,  94]),
#         array([], dtype=int64), array([], dtype=int64), array([74]),
#         array([], dtype=int64), array([259, 158, 318, 387, 453]),
#         array([180, 181,  94]), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64), array([12]),
#         array([12]), array([319, 228, 330, 220, 384]),
#         array([], dtype=int64), array([25]), array([], dtype=int64),
#         array([416, 350, 221, 199, 291]), array([ 40, 128]),
#         array([], dtype=int64), array([ 63, 427, 149, 240, 315]),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64),
#         array([266,  79, 456, 314, 419, 243, 491, 368]),
#         array([], dtype=int64), array([269, 388,  56, 160, 426, 313]),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([293, 251, 402, 345]), array([453]),
#         array([], dtype=int64), array([], dtype=int64),
#         array([409, 346, 242, 191, 294,  53]), array([], dtype=int64),
#         array([259, 158, 318, 387, 453]), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64), array([370, 329]),
#         array([160, 313]), array([197,  42, 239]), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([259, 158, 318, 387]),
#         array([156, 266,  79, 456, 419, 243, 368]), array([], dtype=int64),
#         array([438, 469]), array([], dtype=int64), array([], dtype=int64),
#         array([120,  80, 162, 350, 291]), array([], dtype=int64),
#         array([], dtype=int64),
#         array([371, 132, 415, 296, 416, 350, 221, 291]),
#         array([416, 350, 221, 199, 291]), array([371, 248, 132, 415, 296]),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([181,  94]), array([], dtype=int64),
#         array([145,  89, 360,  69, 295, 241]), array([429]),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([220]), array([], dtype=int64),
#         array([377]), array([50]), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([259, 158, 318, 387]), array([ 63, 149, 240, 315]),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([456, 314, 419, 243, 491, 368]), array([], dtype=int64),
#         array([], dtype=int64), array([259, 387, 453]),
#         array([409, 346, 242, 191, 294,  53]), array([], dtype=int64),
#         array([], dtype=int64), array([293, 251, 402, 345]),
#         array([269, 388,  56, 160, 426, 313]), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([324, 197,  42, 239]), array([], dtype=int64),
#         array([], dtype=int64), array([416, 350, 221, 199, 291]),
#         array([], dtype=int64), array([], dtype=int64), array([370, 329]),
#         array([], dtype=int64), array([319, 384]), array([120,  80, 162]),
#         array([371, 248, 132, 415, 296, 416]), array([438, 469]),
#         array([], dtype=int64), array([438, 469]), array([], dtype=int64),
#         array([], dtype=int64), array([12]), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([50]), array([], dtype=int64),
#         array([], dtype=int64), array([181,  94]), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64), array([394, 442]),
#         array([], dtype=int64), array([156, 266,  79, 456, 419, 243, 368]),
#         array([383, 178,  97, 103, 131, 277]),
#         array([409, 455, 242, 473,  51]), array([], dtype=int64),
#         array([], dtype=int64), array([464]), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64),
#         array([371, 248, 132, 415, 296, 416, 350, 221, 291]),
#         array([], dtype=int64), array([ 80, 162]), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([416, 350, 221, 199, 291]),
#         array([], dtype=int64), array([162]), array([319, 384]),
#         array([], dtype=int64), array([], dtype=int64), array([438, 469]),
#         array([], dtype=int64), array([156, 266,  79, 243, 368]),
#         array([ 75, 409, 346, 242, 191, 294,  53]), array([], dtype=int64),
#         array([259, 158, 318, 387]), array([], dtype=int64),
#         array([197,  42, 239]), array([293, 470, 453, 251, 402, 345]),
#         array([470, 453, 402]), array([], dtype=int64), array([464]),
#         array([], dtype=int64), array([456, 314, 419, 243, 491, 368]),
#         array([], dtype=int64), array([394, 442]), array([], dtype=int64),
#         array([370, 329]), array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64), array([447, 495]),
#         array([], dtype=int64), array([ 63, 149, 240, 315]),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([447, 495]),
#         array([274, 498, 361, 394, 442]), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([120,  80, 162]), array([324, 197,  42, 239]),
#         array([266,  79, 456, 314, 419, 243, 491, 368]),
#         array([ 75, 409, 455, 346, 242, 191, 294, 473]),
#         array([470, 453, 402, 345]), array([327]), array([], dtype=int64),
#         array([], dtype=int64), array([438, 469]), array([478, 464]),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([464]), array([464, 313]),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([181,  94]), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([319, 384]),
#         array([269, 388,  56, 160, 426, 313]),
#         array([ 92,  97, 277, 370, 329]), array([], dtype=int64),
#         array([371, 248, 132, 415, 296]), array([], dtype=int64),
#         array([120, 132, 415, 296, 416, 350, 221, 291]),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([409, 455, 346, 473]), array([], dtype=int64),
#         array([167, 225, 479, 388,  32, 426]), array([], dtype=int64),
#         array([269, 388, 478,  56, 160, 426, 464, 313]),
#         array([], dtype=int64),
#         array([156, 266,  79, 456, 314, 419, 243, 491, 368]),
#         array([ 81, 440, 255, 279]), array([], dtype=int64),
#         array([470, 453, 402, 345]), array([324, 197,  42, 239]),
#         array([274, 498, 361, 394, 442]), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([215, 477, 459, 122, 413, 367, 287]),
#         array([], dtype=int64), array([76,  8]), array([], dtype=int64),
#         array([], dtype=int64), array([ 81, 440, 327]),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([438, 469]), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([327, 483, 428]), array([], dtype=int64), array([120]),
#         array([293, 470, 453, 251, 402, 345]), array([], dtype=int64),
#         array([456, 314, 419, 243, 491, 368]), array([], dtype=int64),
#         array([409, 455, 346, 242, 473,  51]), array([197,  42, 239]),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([215, 477, 459, 122, 413, 367, 287]),
#         array([], dtype=int64), array([], dtype=int64),
#         array([478,  56, 464]), array([ 81, 440, 255, 279]),
#         array([], dtype=int64), array([479]), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64),
#         array([], dtype=int64), array([], dtype=int64), array([76]),
#         array([], dtype=int64), array([], dtype=int64), array([438, 469]),
#         array([], dtype=int64)], dtype=object))

# %%
def nnKeyPoints(descriptor,img1,img2,max_eps):
    #-- Step 0: Load images
    im1 = cv2.imread(img1)
    im1 = cv2.cvtColor(im1,cv2.COLOR_BGR2GRAY)
    im2 = cv2.imread(img2)
    im2 = cv2.cvtColor(im2,cv2.COLOR_BGR2GRAY)
    #-- Step 1: Detect the keypoints using SURF Detector, compute the descriptors
    if(descriptor == 'SIFT'):
        detector = cv2.xfeatures2d.SIFT_create()
    elif(descriptor == 'SURF'):
        detector = cv2.xfeatures2d.SURF_create(400)
    elif(descriptor == 'ORB'):
        detector = cv2.ORB_create()
    kp1, _ = detector.detectAndCompute(im1, None)
    kp2, _ = detector.detectAndCompute(im2, None)
    
    nn = NearestNeighbors(n_neighbors=1)
    kp1 = np.array(list(map(lambda x: [x.pt[0], x.pt[1]], kp1)))
    kp2 = np.array(list(map(lambda x: [x.pt[0], x.pt[1]], kp2)))

    points = 50
    
    epsilons = []
    allTheCounts = []
    for eps in np.linspace(0,max_eps,points):
        print(f'\r{(eps/max_eps)*50:.2f}%',end='')
        precision = []
        counts = np.zeros(len(kp1))
        for cp in kp2:
            found = 0
            for i, gt in enumerate(kp1):
                if(np.sqrt((cp.pt[0]-gt.pt[0])**2+(cp.pt[1]-gt.pt[1])**2) <= eps):
                    found = 1
                    counts[i] += 1
                    break
                    
            precision.append(found)
        epsilons.append(precision)
        allTheCounts.append(counts)
    epsilons = np.array(epsilons)
    precisions = [epsilons[i].mean() for i in range(epsilons.shape[0])]


    epsilons = []
    for eps in np.linspace(0,max_eps,points):
        print(f'\r{(eps/max_eps)*50+50:.2f}%',end='')
        recall = []
        counts = np.zeros(len(kp2))
        for gt in kp1:
            found = 0
            for i,cp in enumerate(kp2):
                if(np.sqrt((cp.pt[0]-gt.pt[0])**2+(cp.pt[1]-gt.pt[1])**2) <= eps):
                    found = 1
                    counts[i] += 1
                    break
            recall.append(found)
        epsilons.append(recall)
        allTheCounts.append(counts)
    epsilons = np.array(epsilons)
    recalls = [epsilons[i].mean() for i in range(epsilons.shape[0])]
    
    return precisions, recalls

# %% [markdown]
# # Super point

# %%
model = SuperPointNet()

# %%
model.load_state_dict(torch.load('pytorchsuperpointmaster/pretrained/superpoint_v1.pth'))
# Out:
# <All keys matched successfully>

# %%
model.eval()
# Out:
# SuperPointNet(
#   (relu): ReLU(inplace=True)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv1a): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv1b): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2a): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2b): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3a): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3b): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4a): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4b): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (convPa): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (convPb): Conv2d(256, 65, kernel_size=(1, 1), stride=(1, 1))
#   (convDa): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (convDb): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
im1 = cv2.imread(im1)
im1 = cv2.cvtColor(im1,cv2.COLOR_BGR2GRAY)
im1 = cv2.resize(im1,(640,480))
im1 = im1.astype(np.float32)
plt.imshow(im1)
plt.show()
print(im1.dtype)

im2 = cv2.imread(im2)
im2 = cv2.cvtColor(im2,cv2.COLOR_BGR2GRAY)
im2 = cv2.resize(im2,(640,480))
im2 = im2.astype(np.float32)
plt.imshow(im2)
plt.show()
print(im2.dtype)
# Out:
# float32
# float32

# %%
kp1, des1 = model(torch.from_numpy(im1[np.newaxis,np.newaxis,:,:]))
kp2, des2 = model(torch.from_numpy(im2[np.newaxis,np.newaxis,:,:]))

# %%
print(kp1.shape)
print(des1.shape)
# Out:
# torch.Size([1, 65, 60, 80])
# torch.Size([1, 256, 60, 80])

# %%
matcher = cv2.DescriptorMatcher_create(cv2.DescriptorMatcher_FLANNBASED)
knn_matches = matcher.knnMatch(des1, des2, 2)
#-- Filter matches using the Lowe's ratio test
ratio_thresh = 0.7
good_matches = []
for m,n in knn_matches:
    if m.distance < ratio_thresh * n.distance:
        good_matches.append(m)
#-- Draw matches
img_matches = np.empty((max(im1.shape[0], im2.shape[0]), im1.shape[1]+im2.shape[1], 3), dtype=np.uint8)
cv2.drawMatches(im1, kp1, im2, kp2, good_matches, img_matches, 1, matchColor=-1, flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)
#-- Show detected matches
plt.figure(figsize=(18,36))
plt.imshow(img_matches)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-154-278a366e0f72> in <module>
#       9 #-- Draw matches
#      10 img_matches = np.empty((max(im1.shape[0], im2.shape[0]), im1.shape[1]+im2.shape[1], 3), dtype=np.uint8)
# ---> 11 cv2.drawMatches(im1, kp1, im2, kp2, good_matches, img_matches, 1, matchColor=-1, flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)
#      12 #-- Show detected matches
#      13 plt.figure(figsize=(18,36))
#
# error: OpenCV(4.5.4-dev) :-1: error: (-5:Bad argument) in function 'drawMatches'
# > Overload resolution failed:
# >  - argument for drawMatches() given by name ('matchColor') and position (7)
# >  - argument for drawMatches() given by name ('matchColor') and position (7)
# >  - Can't parse 'keypoints1'. Sequence item with index 0 has a wrong type
# >  - Can't parse 'keypoints1'. Sequence item with index 0 has a wrong type

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=715a1e20-cf88-4392-be19-7391a8dd0abf' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
